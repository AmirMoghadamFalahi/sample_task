# %% [markdown]
# <a href="https://colab.research.google.com/github/AmirMoghadamFalahi/sample_task/blob/main/model/information_extraction_v0_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction
#
# In this notebook, I want to just implement what's one my mind to extract information about different companies from autonews.com articles. This information would for example be partnerships, costumers, etc.
#
# For this, we will do the following steps:
#
# 1.   Installing and importing required packages and libraries
# 2.   Making and ElasticSearch document store to store our data in next steps
# 3.   Reading the dataset from csv files
# 4.   Obtaining all company names from our dataset using SpaCy library and storing them
# 5.   Converting the data to a format that fits Haystack's requirments
# 6.   Indexing the data into our ElasticSearch
# 7.   Using pretrained models of Hugging Face to make Haystack's retriever, reader and finder.
# 8.   Using company names from step 4 to make some question about the information we want to extract and letting Haystack to search for the answers.
# 9.   Checking whether obtained answers are compatible with our previous knowledge from step 4. For example, if the model predict some company names which are in partnership with company "X", then these companies should be on our company list from step 4.
# 10.  Cross-validate the asnwers with itself and test the model results.

# %% [markdown]
# # Step 1. Installing and importing required packages and libraries

# %%
# it seems that something's wrong with the urllib3, 
# which is one of Haystacks package requirements. So I would update it to 
# another version

! pip install urllib3==1.25.10
# Out:
# Collecting urllib3==1.25.10
#   Downloading https://files.pythonhosted.org/packages/9f/f0/a391d1463ebb1b233795cabfc0ef38d3db4442339de68f847026199e69d7/urllib3-1.25.10-py2.py3-none-any.whl (127kB)
#      |████████████████████████████████| 133kB 9.6MB/s
# ERROR: kaggle 1.5.8 has requirement urllib3<1.25,>=1.21.1, but you'll have urllib3 1.25.10 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# Installing collected packages: urllib3
#   Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# Successfully installed urllib3-1.25.10

# %%
# Install the latest release of Haystack in your own environment 
# !pip install git+https://github.com/deepset-ai/haystack.git
# Out:
# Collecting git+https://github.com/deepset-ai/haystack.git
#   Cloning https://github.com/deepset-ai/haystack.git to /tmp/pip-req-build-_d3b5l26
#   Running command git clone -q https://github.com/deepset-ai/haystack.git /tmp/pip-req-build-_d3b5l26
# Collecting farm==0.4.9
#   Downloading https://files.pythonhosted.org/packages/7b/6a/d30bc97eaca322d35979f7a9f8fd8102e53833d3eb5b3bd02add1196ac94/farm-0.4.9-py3-none-any.whl (190kB)
#      |████████████████████████████████| 194kB 10.3MB/s
# Collecting fastapi
#   Downloading https://files.pythonhosted.org/packages/48/65/454fb440d48098845875b5ba8599efafee1efabb97720a584c78674e6d26/fastapi-0.61.1-py3-none-any.whl (48kB)
#      |████████████████████████████████| 51kB 4.2MB/s
# Collecting uvicorn
#   Downloading https://files.pythonhosted.org/packages/30/cc/01cc4cb980dfcf04eb283b6497c7f280928a0b02c68c0f85b6901e7716ae/uvicorn-0.12.2-py3-none-any.whl (45kB)
#      |████████████████████████████████| 51kB 7.2MB/s
# Collecting gunicorn
#   Downloading https://files.pythonhosted.org/packages/69/ca/926f7cd3a2014b16870086b2d0fdc84a9e49473c68a8dff8b57f7c156f43/gunicorn-20.0.4-py2.py3-none-any.whl (77kB)
#      |████████████████████████████████| 81kB 8.4MB/s
# Requirement already satisfied: pandas in /usr/local/lib/python3.6/dist-packages (from farm-haystack==0.4.0) (1.1.2)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.6/dist-packages (from farm-haystack==0.4.0) (0.0)
# Collecting elasticsearch
#   Downloading https://files.pythonhosted.org/packages/e4/b7/f8f03019089671486e2910282c1b6fce26ccc8a513322df72ac8994ab2de/elasticsearch-7.9.1-py2.py3-none-any.whl (219kB)
#      |████████████████████████████████| 225kB 28.7MB/s
# Collecting elastic-apm
#   Downloading https://files.pythonhosted.org/packages/b0/eb/583f6a48d2887e228e4db9325a8480d54154b21c693abac7902df2ee1e8e/elastic_apm-5.9.0-cp36-cp36m-manylinux2010_x86_64.whl (312kB)
#      |████████████████████████████████| 317kB 51.5MB/s
# Collecting tox
#   Downloading https://files.pythonhosted.org/packages/e0/79/5915b9dad867e89bb6495456acfe5d4e2287e74dfa29c059f7b127d5480e/tox-3.20.1-py2.py3-none-any.whl (83kB)
#      |████████████████████████████████| 92kB 11.3MB/s
# Requirement already satisfied: coverage in /usr/local/lib/python3.6/dist-packages (from farm-haystack==0.4.0) (3.7.1)
# Collecting langdetect
#   Downloading https://files.pythonhosted.org/packages/56/a3/8407c1e62d5980188b4acc45ef3d94b933d14a2ebc9ef3505f22cf772570/langdetect-1.0.8.tar.gz (981kB)
#      |████████████████████████████████| 983kB 49.1MB/s
# Collecting python-multipart
#   Downloading https://files.pythonhosted.org/packages/46/40/a933ac570bf7aad12a298fc53458115cc74053474a72fbb8201d7dc06d3d/python-multipart-0.0.5.tar.gz
# Collecting python-docx
#   Downloading https://files.pythonhosted.org/packages/e4/83/c66a1934ed5ed8ab1dbb9931f1779079f8bca0f6bbc5793c06c4b5e7d671/python-docx-0.8.10.tar.gz (5.5MB)
#      |████████████████████████████████| 5.5MB 45.9MB/s
# Collecting sqlalchemy_utils
#   Downloading https://files.pythonhosted.org/packages/14/68/e5301c4c960c79a32333b8805e52cb69d3d237aa869a773b4157ccb3eb26/SQLAlchemy-Utils-0.36.8.tar.gz (138kB)
#      |████████████████████████████████| 143kB 53.9MB/s
# Collecting tika
#   Downloading https://files.pythonhosted.org/packages/96/07/244fbb9c74c0de8a3745cc9f3f496077a29f6418c7cbd90d68fd799574cb/tika-1.24.tar.gz
# Collecting httptools
#   Downloading https://files.pythonhosted.org/packages/b1/a6/dc1e7e8f4049ab70d52c9690ec10652e268ab2542853033cc1d539594102/httptools-0.1.1-cp36-cp36m-manylinux1_x86_64.whl (216kB)
#      |████████████████████████████████| 225kB 40.0MB/s
# Requirement already satisfied: nltk in /usr/local/lib/python3.6/dist-packages (from farm-haystack==0.4.0) (3.2.5)
# Requirement already satisfied: more_itertools in /usr/local/lib/python3.6/dist-packages (from farm-haystack==0.4.0) (8.5.0)
# Collecting psycopg2-binary
#   Downloading https://files.pythonhosted.org/packages/f2/1b/720b36697158113ca1b2221a8e96a470088ccf3770d182214689d1a96a07/psycopg2_binary-2.8.6-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 45.5MB/s
# Collecting faiss-cpu
#   Downloading https://files.pythonhosted.org/packages/1d/84/9de38703486d9f00b1a63590887a318d08c52f10f768968bd7626aee75da/faiss_cpu-1.6.3-cp36-cp36m-manylinux2010_x86_64.whl (7.2MB)
#      |████████████████████████████████| 7.2MB 44.1MB/s
# Collecting uvloop
#   Downloading https://files.pythonhosted.org/packages/41/48/586225bbb02d3bdca475b17e4be5ce5b3f09da2d6979f359916c1592a687/uvloop-0.14.0-cp36-cp36m-manylinux2010_x86_64.whl (3.9MB)
#      |████████████████████████████████| 3.9MB 51.1MB/s
# Requirement already satisfied: torch<1.7,>1.5 in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.6.0+cu101)
# Collecting mlflow==1.0.0
#   Downloading https://files.pythonhosted.org/packages/01/ec/8c9448968d4662e8354b9c3a62e635f8929ed507a45af3d9fdb84be51270/mlflow-1.0.0-py3-none-any.whl (47.7MB)
#      |████████████████████████████████| 47.7MB 127kB/s
# Requirement already satisfied: dill in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.3.2)
# Collecting dotmap==1.3.0
#   Downloading https://files.pythonhosted.org/packages/fa/eb/ee5f0358a9e0ede90308d8f34e697e122f191c2702dc4f614eca7770b1eb/dotmap-1.3.0-py3-none-any.whl
# Collecting Werkzeug==0.16.1
#   Downloading https://files.pythonhosted.org/packages/c2/e4/a859d2fe516f466642fa5c6054fd9646271f9da26b0cac0d2f37fc858c8f/Werkzeug-0.16.1-py2.py3-none-any.whl (327kB)
#      |████████████████████████████████| 327kB 54.2MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (2.23.0)
# Requirement already satisfied: flask in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.1.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (50.3.0)
# Collecting flask-restplus
#   Downloading https://files.pythonhosted.org/packages/c2/a6/b17c848771f96ad039ad9e3ea275e842a16c39c4f3eb9f60ee330b20b6c2/flask_restplus-0.13.0-py2.py3-none-any.whl (2.5MB)
#      |████████████████████████████████| 2.5MB 42.0MB/s
# Collecting transformers==3.1.0
#   Downloading https://files.pythonhosted.org/packages/ae/05/c8c55b600308dc04e95100dc8ad8a244dd800fe75dfafcf1d6348c6f6209/transformers-3.1.0-py3-none-any.whl (884kB)
#      |████████████████████████████████| 890kB 49.0MB/s
# Requirement already satisfied: psutil in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (5.4.8)
# Collecting seqeval
#   Downloading https://files.pythonhosted.org/packages/c4/47/f85f522f1f2532ca650474088e4024a9f52d524379bff058eaadf53cb663/seqeval-1.2.1.tar.gz (43kB)
#      |████████████████████████████████| 51kB 8.3MB/s
# Collecting boto3
#   Downloading https://files.pythonhosted.org/packages/30/3c/c9b65c398de6589c93b3c65aa27a695a6cdf7588c50a7934ad3ac6599a8a/boto3-1.16.2-py2.py3-none-any.whl (129kB)
#      |████████████████████████████████| 133kB 52.9MB/s
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (4.41.1)
# Requirement already satisfied: scipy>=1.3.2 in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (1.4.1)
# Collecting flask-cors
#   Downloading https://files.pythonhosted.org/packages/69/7f/d0aeaaafb5c3c76c8d2141dbe2d4f6dca5d6c31872d4e5349768c1958abc/Flask_Cors-3.0.9-py2.py3-none-any.whl
# Requirement already satisfied: wheel in /usr/local/lib/python3.6/dist-packages (from farm==0.4.9->farm-haystack==0.4.0) (0.35.1)
# Collecting pydantic<2.0.0,>=1.0.0
#   Downloading https://files.pythonhosted.org/packages/aa/5f/855412ad12817ae87f1c77d3af2fc384eaed3adfb8f3994816d75483fa20/pydantic-1.6.1-cp36-cp36m-manylinux2014_x86_64.whl (8.7MB)
#      |████████████████████████████████| 8.7MB 34.5MB/s
# Collecting starlette==0.13.6
#   Downloading https://files.pythonhosted.org/packages/c5/a4/c9e228d7d47044ce4c83ba002f28ff479e542455f0499198a3f77c94f564/starlette-0.13.6-py3-none-any.whl (59kB)
#      |████████████████████████████████| 61kB 9.3MB/s
# Requirement already satisfied: click==7.* in /usr/local/lib/python3.6/dist-packages (from uvicorn->farm-haystack==0.4.0) (7.1.2)
# Collecting h11>=0.8
#   Downloading https://files.pythonhosted.org/packages/b2/79/9c5f5cd738ec2a9b26453b3093915c0999f24454e2773921025c03b5509e/h11-0.11.0-py2.py3-none-any.whl (54kB)
#      |████████████████████████████████| 61kB 10.2MB/s
# Requirement already satisfied: typing-extensions; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from uvicorn->farm-haystack==0.4.0) (3.7.4.3)
# Requirement already satisfied: pytz>=2017.2 in /usr/local/lib/python3.6/dist-packages (from pandas->farm-haystack==0.4.0) (2018.9)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.6/dist-packages (from pandas->farm-haystack==0.4.0) (2.8.1)
# Requirement already satisfied: numpy>=1.15.4 in /usr/local/lib/python3.6/dist-packages (from pandas->farm-haystack==0.4.0) (1.18.5)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.6/dist-packages (from sklearn->farm-haystack==0.4.0) (0.22.2.post1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.6/dist-packages (from elasticsearch->farm-haystack==0.4.0) (2020.6.20)
# Requirement already satisfied: urllib3>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from elasticsearch->farm-haystack==0.4.0) (1.25.10)
# Collecting pluggy>=0.12.0
#   Downloading https://files.pythonhosted.org/packages/a0/28/85c7aa31b80d150b772fbe4a229487bc6644da9ccb7e427dd8cc60cb8a62/pluggy-0.13.1-py2.py3-none-any.whl
# Requirement already satisfied: importlib-metadata<3,>=0.12; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (2.0.0)
# Requirement already satisfied: py>=1.4.17 in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (1.9.0)
# Requirement already satisfied: six>=1.14.0 in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (1.15.0)
# Requirement already satisfied: packaging>=14 in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (20.4)
# Requirement already satisfied: toml>=0.9.4 in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (0.10.1)
# Requirement already satisfied: filelock>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from tox->farm-haystack==0.4.0) (3.0.12)
# Collecting virtualenv!=20.0.0,!=20.0.1,!=20.0.2,!=20.0.3,!=20.0.4,!=20.0.5,!=20.0.6,!=20.0.7,>=16.0.0
#   Downloading https://files.pythonhosted.org/packages/a1/4c/d308cd6fcf86099c5f6902a8373940c8f59a2f07d42dc22d35ae798fdd3a/virtualenv-20.0.35-py2.py3-none-any.whl (4.9MB)
#      |████████████████████████████████| 4.9MB 46.4MB/s
# Requirement already satisfied: lxml>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from python-docx->farm-haystack==0.4.0) (4.2.6)
# Requirement already satisfied: SQLAlchemy>=1.0 in /usr/local/lib/python3.6/dist-packages (from sqlalchemy_utils->farm-haystack==0.4.0) (1.3.19)
# Requirement already satisfied: future in /usr/local/lib/python3.6/dist-packages (from torch<1.7,>1.5->farm==0.4.9->farm-haystack==0.4.0) (0.16.0)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.12.4)
# Requirement already satisfied: pyyaml in /usr/local/lib/python3.6/dist-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (3.13)
# Collecting simplejson
#   Downloading https://files.pythonhosted.org/packages/73/96/1e6b19045375890068d7342cbe280dd64ae73fd90b9735b5efb8d1e044a1/simplejson-3.17.2-cp36-cp36m-manylinux2010_x86_64.whl (127kB)
#      |████████████████████████████████| 133kB 57.0MB/s
# Collecting querystring-parser
#   Downloading https://files.pythonhosted.org/packages/4a/fa/f54f5662e0eababf0c49e92fd94bf178888562c0e7b677c8941bbbcd1bd6/querystring_parser-1.2.4.tar.gz
# Collecting alembic
#   Downloading https://files.pythonhosted.org/packages/12/aa/c261dfd7f4ba6ce4701846a2689a46e2a172e012171de4378fc2926e3bf0/alembic-1.4.3-py2.py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 50.9MB/s
# Collecting gitpython>=2.1.0
#   Downloading https://files.pythonhosted.org/packages/c0/d7/b2b0672e0331567157adf9281f41ee731c412ee518ca5e6552c27fa73c91/GitPython-3.1.9-py3-none-any.whl (159kB)
#      |████████████████████████████████| 163kB 56.8MB/s
# Collecting docker>=3.6.0
#   Downloading https://files.pythonhosted.org/packages/9e/8c/8d42dbd83679483db207535f4fb02dc84325fa78b290f057694b057fcd21/docker-4.3.1-py2.py3-none-any.whl (145kB)
#      |████████████████████████████████| 153kB 54.5MB/s
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.6/dist-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.3.1)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.6/dist-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.3)
# Collecting databricks-cli>=0.8.0
#   Downloading https://files.pythonhosted.org/packages/20/d9/01d0bda8d764be9e7448a41c34eec002e67e88e0d558b80d0ba922b4f7f0/databricks-cli-0.13.0.tar.gz (54kB)
#      |████████████████████████████████| 61kB 9.6MB/s
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.6/dist-packages (from mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->farm==0.4.9->farm-haystack==0.4.0) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->farm==0.4.9->farm-haystack==0.4.0) (3.0.4)
# Requirement already satisfied: itsdangerous>=0.24 in /usr/local/lib/python3.6/dist-packages (from flask->farm==0.4.9->farm-haystack==0.4.0) (1.1.0)
# Requirement already satisfied: Jinja2>=2.10.1 in /usr/local/lib/python3.6/dist-packages (from flask->farm==0.4.9->farm-haystack==0.4.0) (2.11.2)
# Collecting aniso8601>=0.82
#   Downloading https://files.pythonhosted.org/packages/eb/e4/787e104b58eadc1a710738d4e418d7e599e4e778e52cb8e5d5ef6ddd5833/aniso8601-8.0.0-py2.py3-none-any.whl (43kB)
#      |████████████████████████████████| 51kB 8.9MB/s
# Requirement already satisfied: jsonschema in /usr/local/lib/python3.6/dist-packages (from flask-restplus->farm==0.4.9->farm-haystack==0.4.0) (2.6.0)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 48.9MB/s
# Collecting tokenizers==0.8.1.rc2
#   Downloading https://files.pythonhosted.org/packages/80/83/8b9fccb9e48eeb575ee19179e2bdde0ee9a1904f97de5f02d19016b8804f/tokenizers-0.8.1rc2-cp36-cp36m-manylinux1_x86_64.whl (3.0MB)
#      |████████████████████████████████| 3.0MB 45.1MB/s
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers==3.1.0->farm==0.4.9->farm-haystack==0.4.0) (0.7)
# Collecting sentencepiece!=0.1.92
#   Downloading https://files.pythonhosted.org/packages/d4/a4/d0a884c4300004a78cca907a6ff9a5e9fe4f090f5d95ab341c53d28cbc58/sentencepiece-0.1.91-cp36-cp36m-manylinux1_x86_64.whl (1.1MB)
#      |████████████████████████████████| 1.1MB 49.4MB/s
# Collecting botocore<1.20.0,>=1.19.2
#   Downloading https://files.pythonhosted.org/packages/1f/96/35fa364675cf17e3a190ae08716ac4b078ca86a62ef071d32cd8b86d52bc/botocore-1.19.2-py2.py3-none-any.whl (6.7MB)
#      |████████████████████████████████| 6.7MB 44.9MB/s
# Collecting jmespath<1.0.0,>=0.7.1
#   Downloading https://files.pythonhosted.org/packages/07/cb/5f001272b6faeb23c1c9e0acc04d48eaaf5c862c17709d20e3469c6e0139/jmespath-0.10.0-py2.py3-none-any.whl
# Collecting s3transfer<0.4.0,>=0.3.0
#   Downloading https://files.pythonhosted.org/packages/69/79/e6afb3d8b0b4e96cefbdc690f741d7dd24547ff1f94240c997a26fa908d3/s3transfer-0.3.3-py2.py3-none-any.whl (69kB)
#      |████████████████████████████████| 71kB 9.8MB/s
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.6/dist-packages (from scikit-learn->sklearn->farm-haystack==0.4.0) (0.16.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata<3,>=0.12; python_version < "3.8"->tox->farm-haystack==0.4.0) (3.2.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging>=14->tox->farm-haystack==0.4.0) (2.4.7)
# Collecting appdirs<2,>=1.4.3
#   Downloading https://files.pythonhosted.org/packages/3b/00/2344469e2084fb287c2e0b57b72910309874c3245463acd6cf5e3db69324/appdirs-1.4.4-py2.py3-none-any.whl
# Collecting distlib<1,>=0.3.1
#   Downloading https://files.pythonhosted.org/packages/f5/0a/490fa011d699bb5a5f3a0cf57de82237f52a6db9d40f33c53b2736c9a1f9/distlib-0.3.1-py2.py3-none-any.whl (335kB)
#      |████████████████████████████████| 337kB 57.4MB/s
# Collecting importlib-resources>=1.0; python_version < "3.7"
#   Downloading https://files.pythonhosted.org/packages/ba/03/0f9595c0c2ef12590877f3c47e5f579759ce5caf817f8256d5dcbd8a1177/importlib_resources-3.0.0-py2.py3-none-any.whl
# Collecting Mako
#   Downloading https://files.pythonhosted.org/packages/a6/37/0e706200d22172eb8fa17d68a7ae22dec7631a0a92266634fb518a88a5b2/Mako-1.1.3-py2.py3-none-any.whl (75kB)
#      |████████████████████████████████| 81kB 12.3MB/s
# Collecting python-editor>=0.3
#   Downloading https://files.pythonhosted.org/packages/c6/d3/201fc3abe391bbae6606e6f1d598c15d367033332bd54352b12f35513717/python_editor-1.0.4-py3-none-any.whl
# Collecting gitdb<5,>=4.0.1
#   Downloading https://files.pythonhosted.org/packages/48/11/d1800bca0a3bae820b84b7d813ad1eff15a48a64caea9c823fc8c1b119e8/gitdb-4.0.5-py3-none-any.whl (63kB)
#      |████████████████████████████████| 71kB 11.9MB/s
# Collecting websocket-client>=0.32.0
#   Downloading https://files.pythonhosted.org/packages/4c/5f/f61b420143ed1c8dc69f9eaec5ff1ac36109d52c80de49d66e0c36c3dfdf/websocket_client-0.57.0-py2.py3-none-any.whl (200kB)
#      |████████████████████████████████| 204kB 56.1MB/s
# Requirement already satisfied: tabulate>=0.7.7 in /usr/local/lib/python3.6/dist-packages (from databricks-cli>=0.8.0->mlflow==1.0.0->farm==0.4.9->farm-haystack==0.4.0) (0.8.7)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from Jinja2>=2.10.1->flask->farm==0.4.9->farm-haystack==0.4.0) (1.1.1)
# Collecting smmap<4,>=3.0.1
#   Downloading https://files.pythonhosted.org/packages/b0/9a/4d409a6234eb940e6a78dfdfc66156e7522262f5f2fecca07dc55915952d/smmap-3.0.4-py2.py3-none-any.whl
# Building wheels for collected packages: farm-haystack, langdetect, python-multipart, python-docx, sqlalchemy-utils, tika, seqeval, querystring-parser, databricks-cli, sacremoses
#   Building wheel for farm-haystack (setup.py) ... done
#   Created wheel for farm-haystack: filename=farm_haystack-0.4.0-cp36-none-any.whl size=88142 sha256=86de7d6fc4710f079453789a76e7db063bec7e305b2de53260d446fecf59e1b7
#   Stored in directory: /tmp/pip-ephem-wheel-cache-rfbhqxwk/wheels/ab/41/a4/4fbf362de283352078ecb6705c08b6525347aaea2eead2a60c
#   Building wheel for langdetect (setup.py) ... done
#   Created wheel for langdetect: filename=langdetect-1.0.8-cp36-none-any.whl size=993195 sha256=441b062046527ebdbc218049b7319d0be09cbcd69d98190dc082a80bc081975c
#   Stored in directory: /root/.cache/pip/wheels/8d/b3/aa/6d99de9f3841d7d3d40a60ea06e6d669e8e5012e6c8b947a57
#   Building wheel for python-multipart (setup.py) ... done
#   Created wheel for python-multipart: filename=python_multipart-0.0.5-cp36-none-any.whl size=31671 sha256=98e56da775e438144ef607f59a3203cd3915a61c1e8344f44f7393fa0ecc092a
#   Stored in directory: /root/.cache/pip/wheels/f0/e6/66/14a866a3cbd6a0cabfbef91f7edf40aa03595ef6c88d6d1be4
#   Building wheel for python-docx (setup.py) ... done
#   Created wheel for python-docx: filename=python_docx-0.8.10-cp36-none-any.whl size=184491 sha256=3d456de53617d7f46059c3050e76c3847211152f6ff466c4f48b8ba753bd3796
#   Stored in directory: /root/.cache/pip/wheels/18/0b/a0/1dd62ff812c857c9e487f27d80d53d2b40531bec1acecfa47b
#   Building wheel for sqlalchemy-utils (setup.py) ... done
#   Created wheel for sqlalchemy-utils: filename=SQLAlchemy_Utils-0.36.8-py2.py3-none-any.whl size=93219 sha256=3ceac403a7aa48b2d803fac6e1dd5edc2830f7e0d03208c1cac09bf30abf23cb
#   Stored in directory: /root/.cache/pip/wheels/68/31/b6/a96bf6868f42753696d647846c9a0f8e51bd99295790d07660
#   Building wheel for tika (setup.py) ... done
#   Created wheel for tika: filename=tika-1.24-cp36-none-any.whl size=32884 sha256=f680d3659fab75377466c02b6fb7842be7f85c6b42c651ae8a5a5bf1cfe97677
#   Stored in directory: /root/.cache/pip/wheels/73/9c/f5/0b1b738442fc2a2862bef95b908b374f8e80215550fb2a8975
#   Building wheel for seqeval (setup.py) ... done
#   Created wheel for seqeval: filename=seqeval-1.2.1-cp36-none-any.whl size=16168 sha256=7e0b89cf89b00bca17bd6738017bee8aad7929c4dab0964f55842e50a1754a9e
#   Stored in directory: /root/.cache/pip/wheels/b4/42/c0/e2d946497f714404c0b78a0ab4c7f45222a293f49320932463
#   Building wheel for querystring-parser (setup.py) ... done
#   Created wheel for querystring-parser: filename=querystring_parser-1.2.4-cp36-none-any.whl size=7078 sha256=fd3734a1a388019dd1440b892dc32a54217d4dadcde47f706e89ea3a09c17592
#   Stored in directory: /root/.cache/pip/wheels/1e/41/34/23ebf5d1089a9aed847951e0ee375426eb4ad0a7079d88d41e
#   Building wheel for databricks-cli (setup.py) ... done
#   Created wheel for databricks-cli: filename=databricks_cli-0.13.0-cp36-none-any.whl size=100347 sha256=cc77b09026350b56b9a23aa11dc14e877c846ea7635921076430ac312b92da9e
#   Stored in directory: /root/.cache/pip/wheels/d3/ba/45/11e7abe40b8e21f4aab12a3051e269b24d17f2b288bb7418d5
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893257 sha256=6551e7a01267c56eaaa795427f615d93e884650c95f3c4b3c10b81d26fa92627
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built farm-haystack langdetect python-multipart python-docx sqlalchemy-utils tika seqeval querystring-parser databricks-cli sacremoses
# ERROR: pytest 3.6.4 has requirement pluggy<0.8,>=0.5, but you'll have pluggy 0.13.1 which is incompatible.
# ERROR: datascience 0.10.6 has requirement folium==0.2.1, but you'll have folium 0.8.3 which is incompatible.
# ERROR: seqeval 1.2.1 has requirement numpy==1.19.2, but you'll have numpy 1.18.5 which is incompatible.
# ERROR: seqeval 1.2.1 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 0.22.2.post1 which is incompatible.
# Installing collected packages: gunicorn, simplejson, querystring-parser, Mako, python-editor, alembic, smmap, gitdb, gitpython, websocket-client, docker, databricks-cli, mlflow, dotmap, Werkzeug, aniso8601, flask-restplus, sacremoses, tokenizers, sentencepiece, transformers, seqeval, jmespath, botocore, s3transfer, boto3, flask-cors, farm, pydantic, starlette, fastapi, h11, uvicorn, elasticsearch, elastic-apm, pluggy, appdirs, distlib, importlib-resources, virtualenv, tox, langdetect, python-multipart, python-docx, sqlalchemy-utils, tika, httptools, psycopg2-binary, faiss-cpu, uvloop, farm-haystack
#   Found existing installation: Werkzeug 1.0.1
#     Uninstalling Werkzeug-1.0.1:
#       Successfully uninstalled Werkzeug-1.0.1
#   Found existing installation: pluggy 0.7.1
#     Uninstalling pluggy-0.7.1:
#       Successfully uninstalled pluggy-0.7.1
# Successfully installed Mako-1.1.3 Werkzeug-0.16.1 alembic-1.4.3 aniso8601-8.0.0 appdirs-1.4.4 boto3-1.16.2 botocore-1.19.2 databricks-cli-0.13.0 distlib-0.3.1 docker-4.3.1 dotmap-1.3.0 elastic-apm-5.9.0 elasticsearch-7.9.1 faiss-cpu-1.6.3 farm-0.4.9 farm-haystack-0.4.0 fastapi-0.61.1 flask-cors-3.0.9 flask-restplus-0.13.0 gitdb-4.0.5 gitpython-3.1.9 gunicorn-20.0.4 h11-0.11.0 httptools-0.1.1 importlib-resources-3.0.0 jmespath-0.10.0 langdetect-1.0.8 mlflow-1.0.0 pluggy-0.13.1 psycopg2-binary-2.8.6 pydantic-1.6.1 python-docx-0.8.10 python-editor-1.0.4 python-multipart-0.0.5 querystring-parser-1.2.4 s3transfer-0.3.3 sacremoses-0.0.43 sentencepiece-0.1.91 seqeval-1.2.1 simplejson-3.17.2 smmap-3.0.4 sqlalchemy-utils-0.36.8 starlette-0.13.6 tika-1.24 tokenizers-0.8.1rc2 tox-3.20.1 transformers-3.1.0 uvicorn-0.12.2 uvloop-0.14.0 virtualenv-20.0.35 websocket-client-0.57.0

# %%
# installing ElasticSearch and making 
! wget https://artifacts.elastic.co/downloads/elasticsearch/elasticsearch-7.6.2-linux-x86_64.tar.gz -q
! tar -xzf elasticsearch-7.6.2-linux-x86_64.tar.gz
! chown -R daemon:daemon elasticsearch-7.6.2

import os
from subprocess import Popen, PIPE, STDOUT
es_server = Popen(['elasticsearch-7.6.2/bin/elasticsearch'],
                   stdout=PIPE, stderr=STDOUT,
                   preexec_fn=lambda: os.setuid(1)  # as daemon
                  )
# wait until ES has started
! sleep 30

# %%
# importing required libraries
import numpy as np
import pandas as pd
import time
import json
import zipfile
import itertools
import os
import sys

# if you get error on importing urllib3 package please just comment line 30 of
# /usr/local/lib/python3.6/dist-packages/botocore/utils.py 
# it seems something's wrong with this package
# you can also track this issue here:
# https://github.com/boto/botocore/issues/2187

from haystack.document_store.elasticsearch import ElasticsearchDocumentStore
from haystack.retriever.sparse import ElasticsearchRetriever
from haystack.retriever.dense import EmbeddingRetriever, DensePassageRetriever
from haystack.reader.farm import FARMReader
from haystack import Finder

import spacy

# %%
! python -m spacy download en_core_web_md
import en_core_web_md
# Out:
# Collecting en_core_web_md==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_md-2.2.5/en_core_web_md-2.2.5.tar.gz (96.4MB)
#      |████████████████████████████████| 96.4MB 1.1MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.6/dist-packages (from en_core_web_md==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.1.3)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.4.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (0.8.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.0.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.2)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (2.23.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.0)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.18.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (7.4.0)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (1.0.2)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (50.3.0)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.6/dist-packages (from spacy>=2.2.2->en_core_web_md==2.2.5) (4.41.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2020.6.20)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_md==2.2.5) (1.25.10)
# Requirement already satisfied: importlib-metadata>=0.20; python_version < "3.8" in /usr/local/lib/python3.6/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (2.0.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.6/dist-packages (from importlib-metadata>=0.20; python_version < "3.8"->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_md==2.2.5) (3.2.0)
# Building wheels for collected packages: en-core-web-md
#   Building wheel for en-core-web-md (setup.py) ... done
#   Created wheel for en-core-web-md: filename=en_core_web_md-2.2.5-cp36-none-any.whl size=98051305 sha256=60a1b5843954cea11801254351bb9f4a4a67b6d8b814cecc5a62fb6296d0a4bf
#   Stored in directory: /tmp/pip-ephem-wheel-cache-2s2wdu2i/wheels/df/94/ad/f5cf59224cea6b5686ac4fd1ad19c8a07bc026e13c36502d81
# Successfully built en-core-web-md
# Installing collected packages: en-core-web-md
# Successfully installed en-core-web-md-2.2.5
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_md')

# %%
# geting a clone of my GitHub repo that I stored the dataset on

# !git clone https://github.com/AmirMoghadamFalahi/sample_task
# Out:
# Cloning into 'sample_task'...
# remote: Enumerating objects: 77, done.
# remote: Counting objects: 100% (77/77), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 77 (delta 30), reused 24 (delta 4), pack-reused 0
# Unpacking objects: 100% (77/77), done.

# %%
# making a class to turn of unnecassary prints
class HiddenPrints:
    def __enter__(self):
        self._original_stdout = sys.stdout
        sys.stdout = open(os.devnull, 'w')

    def __exit__(self, exc_type, exc_val, exc_tb):
        sys.stdout.close()
        sys.stdout = self._original_stdout

# %% [markdown]
# # Step 2. Making and ElasticSearch document store to store our data in next steps

# %%
document_store = ElasticsearchDocumentStore(host="localhost", username="", 
                                            password="", index="document")
# Out:
# 10/21/2020 22:11:37 - INFO - elasticsearch -   PUT http://localhost:9200/document [status:200 request:0.725s]
# 10/21/2020 22:11:37 - INFO - elasticsearch -   PUT http://localhost:9200/label [status:200 request:0.202s]

# %% [markdown]
# # Step 3. Reading the dataset from csv files

# %%
dataset_path = 'sample_task/dataset/'
csv_path = dataset_path + 'csv_data/'
dataset_zip_list = os.listdir(dataset_path)

for file_name in dataset_zip_list:
  with zipfile.ZipFile(dataset_path + file_name, 'r') as zip_ref:
      zip_ref.extractall(csv_path)

# %%
csv_list = sorted(os.listdir(csv_path))

for i, file_name in enumerate(csv_list):
  # print(i, file_name)

  if i == 0:
    autonews_df = pd.read_csv(csv_path + file_name)
    columns = autonews_df.columns
  else:
    df = pd.read_csv(csv_path + file_name, names=columns)
    autonews_df = pd.concat([autonews_df, df])
    # print(autonews_df.head())
  
autonews_df = autonews_df.reset_index(drop=True)
autonews_df = autonews_df.replace({np.nan: None})

# %%
autonews_df.head()
# Out:
#    id  ...                                                                    paragraph_dic
# 0   1  ...  {"1": "LOS ANGELES — A year ago, the mantra being pushed by Honda executives...
# 1   4  ...  {"1": "Interior supplier Yanfeng has revealed its next step in its effort to...
# 2   6  ...  {"1": "More customers are buying cars using a computer today, but one of a d...
# 3   7  ...  {"1": "As if it hasn't been hard enough recruiting work forces over the past...
# 4   8  ...  {"1": "Nissan is shifting strategy on commercial vehicle sales now that it i...
#
# [5 rows x 9 columns]

# %%
print('shape of dataframe:', autonews_df.shape)
print('dataframe columns:', autonews_df.columns)
# Out:
# shape of dataframe: (50042, 9)
# dataframe columns: Index(['id', 'article_datetime', 'article_timestamp', 'category',
#        'access_control', 'headline', 'link', 'got_single', 'paragraph_dic'],
#       dtype='object')

# %% [markdown]
# # Step 4. Obtaining all company names from our dataset using SpaCy library and storing them
#
# Firstly, we make an string text of all our articles:

# %%
news_lst = []

for i in range(autonews_df.shape[0]):
  dic = json.loads(autonews_df.paragraph_dic[i])
  whole_news = str(autonews_df.headline[i]) + '\n' + '\n'.join(list(dic.values()))
  news_lst.append(whole_news)

# %%
# printing the first article as a sample:
print(news_lst[0])
# Out:
# Carmaker Honda tilts scale to trucks
# LOS ANGELES — A year ago, the mantra being pushed by Honda executives was that "cars matter" — a compelling message for a brand that derived almost half its volume from sedans and hatchbacks at the time.
# But as the market continues its relentless shift toward crossovers and pickups, it turns out that trucks matter more — even at Honda.
# The brand is now implementing a major change in strategy to emphasize the rugged, off-road capability of its light trucks to pick up more market share.
# Honda estimates the overall U.S. auto market this year has shifted to 76 percent light trucks and 24 percent passenger cars. Honda itself has a mix of 56 percent light trucks to 44 percent cars through the third quarter. So for Honda, light trucks clearly are a big opportunity.
# "As the market approaches 80 percent trucks, we have to make sure we play in that pond," said Art St. Cyr, vice president of automobile operations at American Honda Motor Co.
# Doing that, he said, will mean adjusting the styling of key models to reflect more of an off-road ability.
# "We have a very strong light-truck lineup. It's just making sure that customers realize what we have, what our capability is," St. Cyr told Automotive News at Honda's North American headquarters in Southern California last week. "People don't realize what they can do."
# Honda is tackling that perception with fresh product and marketing. Vehicles such as the Ridgeline pickup, the Passport midsize crossover and the Pilot, which all share a platform, are being freshened and redesigned with a more rugged physical presence, executives said.
# Last week, Honda presented the 2021 Ridgeline with revised styling that will go on sale early next year. The freshened pickup gets new sheet metal at the front to give it a chunky hood and square grille similar to most pickups. A new Honda Performance Development package adds fender flares.
# Jay Joseph, vice president of American Honda's marketing division, said the brand is targeting Ridgeline sales to grow from about 35,000 per year to 50,000 based on the redesign and marketing.
# "The knock on [the current model] was that it was too friendly," Joseph said during a marketing presentation last week. "Trucks need to have a little bit of a presence to them, and they need a little bit of physical heft when you walk up to them."
# The first 60-second spot in a new ad campaign ran during an NBA Finals game featuring the Miami Heat and Los Angeles Lakers last week. It features the Ridgeline, Passport and Pilot, along with Honda motorcycles and all-terrain vehicles, to emphasize the brand's rugged DNA.
# "We'd like to get a bigger piece of the midsize-truck pie," said St. Cyr. He mentioned the segment-leading Toyota Tacoma, which sold nearly 250,000 vehicles last year, as a target competitor.
# Although only three Honda light trucks are being featured in the new ad campaign, executives said the subcompact HR-V and compact CR-V crossovers are also being considered for the rugged styling treatment once those models are due for updates.
# "We have a product plan that is appropriate for the market," St. Cyr said. "The market is looking for a certain feel of a vehicle, so obviously we'll play in that ballpark."
# The vehicles, he added, already match the capability of competitors for light off-road activities. But their outward appearance doesn't reflect the vehicles' robust mechanicals and sophisticated all-wheel-drive systems. They are not rock crawlers, but most customers don't need that.
# St. Cyr emphasized that Honda still believes "cars matter" among key demographics.
# "The cars both in the Acura line and the Honda line get many first-time buyers," he said. "Then we can move them up to light trucks."
# But the shift to a more robust truck strategy has been in the works for some time at Honda, executives said, as sedans in the overall market continued to decline year after year despite predictions that they would eventually stabilize.
# This year, Honda and Acura trimmed car models and trim packages. Honda killed the Fit for the U.S. market and discontinued the coupe body style for the Civic. Acura ended sales of the RLX large sedan in the U.S. market, reducing its sedans to two. Acura's new "flagship" vehicle is the MDX crossover, which is being redesigned for the 2022 model year.
# The coronavirus crisis has further shifted consumer tastes toward trucks, in part because of generous incentives that have brought down monthly payments. Buyers also find safety in utility vehicles at a time when they otherwise may feel vulnerable to forces outside their control, analysts said.
# "COVID has put an additional focus on trucks as even more consumers are buying them in response to the virus," said Karl Brauer, executive analyst at ISeeCars.com. "Honda is getting some of that market, but less than more rugged brands because that's what many of these 'pandemic' buyers want."

# %%
# initializing an nlp model from SpaCy pretrained models for NER purpose
nlp = en_core_web_md.load()

# separating ORG names from the texts and getting their occurance count

company_name_counts = {}

for i, article in enumerate(news_lst):

  if i % 1000 == 0:
    print(i)

  doc = nlp(article)
  ner_array = np.array([(X.text, X.label_) for X in doc.ents])
  try:
    companies, counts = np.unique(ner_array[np.where(ner_array[:, 1] == 'ORG')[0], 0], return_counts=True)
  except Exception as e:
    continue
  for i in range(len(companies)):
    if companies[i] not in company_name_counts.keys():
      company_name_counts[companies[i]] = counts[i]
    else:
      company_name_counts[companies[i]] += counts[i]

  # just to check first 10000 articles, it could be commented to check the 
  #   whole dataset
  if i >= 10000:
    break
# Out:
# 0
# 1000
# 2000
# 3000
# 4000
# 5000
# 6000
# 7000
# 8000
# 9000
# 10000

# %%
len(company_name_counts.items())
# Out:
# 19713

# %% [markdown]
# We have extracted more than 19K company names, which is really huge. It seems that some of the names don't really belongs to companies, such as: 'Honda Performance Development', 'ISeeCars.com', 'NBA Finals', 'the Miami Heat', 'Yanfeng Technology Chief Technology'
#
# I would exclude the company names which have occured less than 10 times in whole articles, although it might cause to lose some real company names.
#
# #### **CAUTION**
#
# A better way is to use from other data sources on the Internet to check which one of the names truly belongs to a company and which one doesn't.

# %%
sorted_company_name_counts = {k: int(v) for k, v in 
                              sorted(company_name_counts.items(), 
                                     key=lambda item: -item[1])}

# %%
company_name_counts_array = np.hstack((np.array(list(sorted_company_name_counts.keys())).reshape(-1, 1), 
                                       np.array(list(sorted_company_name_counts.values())).reshape(-1, 1)))
company_name_counts_array = company_name_counts_array[np.where(company_name_counts_array[:, 1].astype(int) > 10)[0]]

# %%
company_names_df = pd.DataFrame(company_name_counts_array, 
                                columns=['company_name', 'occurance_count'])

# %%
print(company_names_df.shape)
# Out:
# (1391, 2)

# %%
company_names_df.head(20)
# Out:
#        company_name occurance_count
# 0              Ford            5715
# 1             Tesla            5367
# 2                GM            4950
# 3            Toyota            3940
# 4            Nissan            3117
# 5               BMW            2949
# 6                VW            2307
# 7                EV            2289
# 8   Automotive News            2072
# 9             Trump            2055
# 10            Honda            1854
# 11          Hyundai            1850
# 12             Audi            1778
# 13              FCA            1621
# 14              F&I            1534
# 15          Daimler            1530
# 16       Volkswagen            1444
# 17            Volvo            1419
# 18          Porsche            1342
# 19   General Motors            1243

# %% [markdown]
# --------------------------------------------------------------------------------
# A better practice is store this company names on a database to be available anytime. But here we just made a dataframe of them on the memory.

# %% [markdown]
# # Step 5. Converting the data to a format that fits Haystack's requirments

# %% [markdown]
# Here I used a function from the previous notebooks. it makes a list of Haystack-ready dictionaries to be inserted into the Elastic Search

# %%
def prepare_data_haystack(dataset):

  final_dicts = []

  for i, dic in enumerate(dataset.paragraph_dic):
    dic = json.loads(dic, encoding='utf-8')
    txt = ('\n'.join(dic.values()))
    dic = {'text': txt, 'meta': {'category': dataset.category[i], 'headline': dataset.headline[i], 
                                'datetime': dataset.article_datetime[i], 'id': dataset.id[i]}}
    final_dicts.append(dic)

  return final_dicts

haystack_dics = prepare_data_haystack(dataset=autonews_df)
print(haystack_dics[0])
# Out:
# {'text': 'LOS ANGELES — A year ago, the mantra being pushed by Honda executives was that "cars matter" — a compelling message for a brand that derived almost half its volume from sedans and hatchbacks at the time.\nBut as the market continues its relentless shift toward crossovers and pickups, it turns out that trucks matter more — even at Honda.\nThe brand is now implementing a major change in strategy to emphasize the rugged, off-road capability of its light trucks to pick up more market share.\nHonda estimates the overall U.S. auto market this year has shifted to 76 percent light trucks and 24 percent passenger cars. Honda itself has a mix of 56 percent light trucks to 44 percent cars through the third quarter. So for Honda, light trucks clearly are a big opportunity.\n"As the market approaches 80 percent trucks, we have to make sure we play in that pond," said Art St. Cyr, vice president of automobile operations at American Honda Motor Co.\nDoing that, he said, will mean adjusting the styling of key models to reflect more of an off-road ability.\n"We have a very strong light-truck lineup. It\'s just making sure that customers realize what we have, what our capability is," St. Cyr told Automotive News at Honda\'s North American headquarters in Southern California last week. "People don\'t realize what they can do."\nHonda is tackling that perception with fresh product and marketing. Vehicles such as the Ridgeline pickup, the Passport midsize crossover and the Pilot, which all share a platform, are being freshened and redesigned with a more rugged physical presence, executives said.\nLast week, Honda presented the 2021 Ridgeline with revised styling that will go on sale early next year. The freshened pickup gets new sheet metal at the front to give it a chunky hood and square grille similar to most pickups. A new Honda Performance Development package adds fender flares.\nJay Joseph, vice president of American Honda\'s marketing division, said the brand is targeting Ridgeline sales to grow from about 35,000 per year to 50,000 based on the redesign and marketing.\n"The knock on [the current model] was that it was too friendly," Joseph said during a marketing presentation last week. "Trucks need to have a little bit of a presence to them, and they need a little bit of physical heft when you walk up to them."\nThe first 60-second spot in a new ad campaign ran during an NBA Finals game featuring the Miami Heat and Los Angeles Lakers last week. It features the Ridgeline, Passport and Pilot, along with Honda motorcycles and all-terrain vehicles, to emphasize the brand\'s rugged DNA.\n"We\'d like to get a bigger piece of the midsize-truck pie," said St. Cyr. He mentioned the segment-leading Toyota Tacoma, which sold nearly 250,000 vehicles last year, as a target competitor.\nAlthough only three Honda light trucks are being featured in the new ad campaign, executives said the subcompact HR-V and compact CR-V crossovers are also being considered for the rugged styling treatment once those models are due for updates.\n"We have a product plan that is appropriate for the market," St. Cyr said. "The market is looking for a certain feel of a vehicle, so obviously we\'ll play in that ballpark."\nThe vehicles, he added, already match the capability of competitors for light off-road activities. But their outward appearance doesn\'t reflect the vehicles\' robust mechanicals and sophisticated all-wheel-drive systems. They are not rock crawlers, but most customers don\'t need that.\nSt. Cyr emphasized that Honda still believes "cars matter" among key demographics.\n"The cars both in the Acura line and the Honda line get many first-time buyers," he said. "Then we can move them up to light trucks."\nBut the shift to a more robust truck strategy has been in the works for some time at Honda, executives said, as sedans in the overall market continued to decline year after year despite predictions that they would eventually stabilize.\nThis year, Hond ...

# %% [markdown]
# # Step 6. Indexing the data into our ElasticSearch

# %%
document_store.write_documents(haystack_dics)
# Out:
# 10/21/2020 22:23:13 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:2.014s]
# 10/21/2020 22:23:14 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.075s]
# 10/21/2020 22:23:15 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.032s]
# 10/21/2020 22:23:16 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.027s]
# 10/21/2020 22:23:17 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.029s]
# 10/21/2020 22:23:19 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:23:20 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.999s]
# 10/21/2020 22:23:21 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.996s]
# 10/21/2020 22:23:22 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.994s]
# 10/21/2020 22:23:23 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.833s]
# 10/21/2020 22:23:24 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.016s]
# 10/21/2020 22:23:25 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.201s]
# 10/21/2020 22:23:26 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.997s]
# 10/21/2020 22:23:27 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.992s]
# 10/21/2020 22:23:28 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:23:30 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.985s]
# 10/21/2020 22:23:31 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:23:32 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.002s]
# 10/21/2020 22:23:33 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:23:34 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.017s]
# 10/21/2020 22:23:35 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.014s]
# 10/21/2020 22:23:36 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.071s]
# 10/21/2020 22:23:37 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.012s]
# 10/21/2020 22:23:38 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.012s]
# 10/21/2020 22:23:39 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.993s]
# 10/21/2020 22:23:40 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.998s]
# 10/21/2020 22:23:41 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.010s]
# 10/21/2020 22:23:42 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.018s]
# 10/21/2020 22:23:43 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.011s]
# 10/21/2020 22:23:44 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.972s]
# 10/21/2020 22:23:46 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:23:47 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.998s]
# 10/21/2020 22:23:48 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.982s]
# 10/21/2020 22:23:49 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.007s]
# 10/21/2020 22:23:50 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:23:51 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.010s]
# 10/21/2020 22:23:52 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.965s]
# 10/21/2020 22:23:53 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.013s]
# 10/21/2020 22:23:54 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.978s]
# 10/21/2020 22:23:55 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.009s]
# 10/21/2020 22:23:56 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.963s]
# 10/21/2020 22:23:57 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.006s]
# 10/21/2020 22:23:58 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.004s]
# 10/21/2020 22:23:59 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.002s]
# 10/21/2020 22:24:00 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.005s]
# 10/21/2020 22:24:01 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.973s]
# 10/21/2020 22:24:02 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.004s]
# 10/21/2020 22:24:03 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.005s]
# 10/21/2020 22:24:04 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.004s]
# 10/21/2020 22:24:06 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.981s]
# 10/21/2020 22:24:07 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.003s]
# 10/21/2020 22:24:08 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.992s]
# 10/21/2020 22:24:09 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.987s]
# 10/21/2020 22:24:10 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.014s]
# 10/21/2020 22:24:11 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:24:12 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.000s]
# 10/21/2020 22:24:13 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.014s]
# 10/21/2020 22:24:14 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.005s]
# 10/21/2020 22:24:15 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.007s]
# 10/21/2020 22:24:16 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.007s]
# 10/21/2020 22:24:17 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.965s]
# 10/21/2020 22:24:18 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.009s]
# 10/21/2020 22:24:19 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.999s]
# 10/21/2020 22:24:20 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.010s]
# 10/21/2020 22:24:21 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.002s]
# 10/21/2020 22:24:22 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.012s]
# 10/21/2020 22:24:23 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.022s]
# 10/21/2020 22:24:24 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.984s]
# 10/21/2020 22:24:25 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.984s]
# 10/21/2020 22:24:26 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.992s]
# 10/21/2020 22:24:28 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.989s]
# 10/21/2020 22:24:29 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.095s]
# 10/21/2020 22:24:30 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.980s]
# 10/21/2020 22:24:31 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.985s]
# 10/21/2020 22:24:32 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:24:33 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.011s]
# 10/21/2020 22:24:34 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.997s]
# 10/21/2020 22:24:35 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.006s]
# 10/21/2020 22:24:36 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.033s]
# 10/21/2020 22:24:37 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.967s]
# 10/21/2020 22:24:38 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:24:39 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.006s]
# 10/21/2020 22:24:40 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.998s]
# 10/21/2020 22:24:41 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.995s]
# 10/21/2020 22:24:42 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.967s]
# 10/21/2020 22:24:44 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.024s]
# 10/21/2020 22:24:45 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.978s]
# 10/21/2020 22:24:46 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.005s]
# 10/21/2020 22:24:47 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.995s]
# 10/21/2020 22:24:48 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:24:49 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.001s]
# 10/21/2020 22:24:50 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.022s]
# 10/21/2020 22:24:51 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.979s]
# 10/21/2020 22:24:52 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.996s]
# 10/21/2020 22:24:53 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.000s]
# 10/21/2020 22:24:54 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.004s]
# 10/21/2020 22:24:55 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.998s]
# 10/21/2020 22:24:56 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.000s]
# 10/21/2020 22:24:57 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:0.975s]
# 10/21/2020 22:24:58 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.011s]
# 10/21/2020 22:24:59 - INFO - elasticsearch -   POST http://localhost:9200/_bulk?refresh=wait_for [status:200 request:1.002s]

# %% [markdown]
# # Step 7. Using pretrained models of Hugging Face to make Haystack's retriever, reader and finder.

# %% [markdown]
# Here I used `ElasticsearchRetriever`, and it seems to be good enough. It is also so fast.
#
# But other alternatives such as embedding models could be used here.
#
# The best approach is to check a bunch of available models and in search of the best results.

# %%
retriever = ElasticsearchRetriever(document_store=document_store)
# retriever = DensePassageRetriever(document_store=document_store,
#                                   query_embedding_model="facebook/dpr-question_encoder-single-nq-base",
#                                   passage_embedding_model="facebook/dpr-ctx_encoder-single-nq-base",
#                                   use_gpu=True,
#                                   embed_title=True,
#                                   max_seq_len=256,
#                                   batch_size=16,
#                                   remove_sep_tok_from_untitled_passages=True)

# %% [markdown]
# Likewise, in case of reader, several models from Hugging Face models could be used here.

# %%
reader = FARMReader(model_name_or_path="deepset/roberta-base-squad2", use_gpu=True)
# Out:
# 10/21/2020 22:30:27 - INFO - farm.utils -   device: cuda n_gpu: 1, distributed training: False, automatic mixed precision training: None
# 10/21/2020 22:30:28 - INFO - farm.infer -   Could not find `deepset/roberta-base-squad2` locally. Try to download from model hub ...
# 10/21/2020 22:30:28 - INFO - filelock -   Lock 139937637762664 acquired on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.c6288e0f84ec797ba5c525c923a5bbc479b47c761aded9734a5f6a473b044c8d.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=559.0, style=ProgressStyle(description_…
# 10/21/2020 22:30:28 - INFO - filelock -   Lock 139937637762664 released on /root/.cache/torch/transformers/f7d4b9379a9c487fa03ccf3d8e00058faa9d664cf01fc03409138246f48760da.c6288e0f84ec797ba5c525c923a5bbc479b47c761aded9734a5f6a473b044c8d.lock
# 10/21/2020 22:30:28 - INFO - filelock -   Lock 139937637761712 acquired on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.d045adc91e17ecdf7dc3eeff4c875df94bdf2eb749d72b3ae47ae93f8e85213c.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=498637366.0, style=ProgressStyle(descri…
# 10/21/2020 22:30:35 - INFO - filelock -   Lock 139937637761712 released on /root/.cache/torch/transformers/8c0c8b6371111ac5fbc176aefcf9dbe129db7be654c569b8375dd3712fc4dc67.d045adc91e17ecdf7dc3eeff4c875df94bdf2eb749d72b3ae47ae93f8e85213c.lock
# 10/21/2020 22:30:40 - WARNING - farm.modeling.language_model -   Could not automatically detect from language model name what language it is.
# 	 We guess it's an *ENGLISH* model ...
# 	 If not: Init the language model by supplying the 'language' param.
# 10/21/2020 22:30:46 - WARNING - farm.modeling.prediction_head -   Some unused parameters are passed to the QuestionAnsweringHead. Might not be a problem. Params: {"loss_ignore_index": -1}
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 acquired on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=898822.0, style=ProgressStyle(descripti…
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 released on /root/.cache/torch/transformers/1e3af82648d7190d959a9d76d727ef629b1ca51b3da6ad04039122453cb56307.6a4061e8fc00057d21d80413635a86fdcf55b6e7594ad9e25257d2f99a02f4be.lock
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 acquired on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=456318.0, style=ProgressStyle(descripti…
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 released on /root/.cache/torch/transformers/b901c69e8e7da4a24c635ad81d016d274f174261f4f5c144e43f4b00e242c3b0.70bec105b4158ed9a1747fea67a43f5dee97855c64d62b6ec3742f4cfdb5feda.lock
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 acquired on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.16f949018cf247a2ea7465a74ca9a292212875e5fd72f969e0807011e7f192e4.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=150.0, style=ProgressStyle(description_…
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937617357232 released on /root/.cache/torch/transformers/2d9b03b59a8af464bf4238025a3cf0e5a340b9d0ba77400011e23c130b452510.16f949018cf247a2ea7465a74ca9a292212875e5fd72f969e0807011e7f192e4.lock
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937639109352 acquired on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.100c88dbe27dbd73822c575274ade4eb2427596ac56e96769249b7512341654d.lock
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=189.0, style=ProgressStyle(description_…
# 10/21/2020 22:31:01 - INFO - filelock -   Lock 139937639109352 released on /root/.cache/torch/transformers/507984f2e28c7dfed5db9a20acd68beb969c7f2833abc9e582e967fa0291f3dc.100c88dbe27dbd73822c575274ade4eb2427596ac56e96769249b7512341654d.lock
# 10/21/2020 22:31:02 - INFO - farm.utils -   device: cuda n_gpu: 1, distributed training: False, automatic mixed precision training: None
# 10/21/2020 22:31:02 - INFO - farm.infer -   Got ya 1 parallel workers to do inference ...
# 10/21/2020 22:31:02 - INFO - farm.infer -    0
# 10/21/2020 22:31:02 - INFO - farm.infer -   /w\
# 10/21/2020 22:31:02 - INFO - farm.infer -   /'\
# 10/21/2020 22:31:02 - INFO - farm.infer -

# %%
finder = Finder(reader, retriever)

# %% [markdown]
# # Step 8. Using company names from step 4 to make some question about the information we want to extract and letting Haystack to search for the answers.

# %%
# making a function that generates some questions about partnerships of companies
def get_q_list(company_name: str):
  q_list = []

  q_list.append("which companies are partners of " + company_name)
  q_list.append("what companies are in partnership with " + company_name)
  q_list.append("what companies are " + company_name + "'s business partners?")

  return q_list

# %% [markdown]
# ### **CAUTION**
#
# For simplicity, I just run the pipeline for first 20 companies:

# %%
answer_dict_list = []
num_of_companies_to_extract_partners = 20
TOP_K_RETRIEVER_DEFAULT = 20
TOP_K_READER_DEFAULT = 10

for i in range(num_of_companies_to_extract_partners):

  questions = get_q_list(company_names_df.company_name[i])

  company = company_names_df.company_name[i]
  answers = []
  for q in questions:
    prediction = finder.get_answers(question=q, 
                                    top_k_retriever=TOP_K_RETRIEVER_DEFAULT, 
                                    top_k_reader=TOP_K_READER_DEFAULT)
    answers.append([prediction['answers'][k]['answer'] 
                    for k in range(len(prediction['answers']))])
  answers = list(itertools.chain.from_iterable(answers))

  answer_dict_list.append({'company': company_names_df.company_name[i],
                           'answers': answers})
# Out:
# 10/21/2020 22:31:02 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.259s]
# 10/21/2020 22:31:02 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:02 - INFO - haystack.finder -   Reader is looking for detailed answer in 73054 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  2.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.71 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.42 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.12 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 34.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.80 Batches/s]
# 10/21/2020 22:31:06 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.058s]
# 10/21/2020 22:31:06 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:06 - INFO - haystack.finder -   Reader is looking for detailed answer in 68836 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.62 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.41 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.62 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.77 Batches/s]
# 10/21/2020 22:31:10 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.034s]
# 10/21/2020 22:31:10 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:10 - INFO - haystack.finder -   Reader is looking for detailed answer in 78485 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 36.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.63 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.10 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.54 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.47 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 32.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.10 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.16 Batches/s]
# 10/21/2020 22:31:14 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.044s]
# 10/21/2020 22:31:14 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:14 - INFO - haystack.finder -   Reader is looking for detailed answer in 67065 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.62 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.61 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.00 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.19 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.94 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.94 Batches/s]
# 10/21/2020 22:31:18 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.028s]
# 10/21/2020 22:31:18 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:18 - INFO - haystack.finder -   Reader is looking for detailed answer in 55918 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.86 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.42 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 39.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 40.07 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.12 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 41.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.49 Batches/s]
# 10/21/2020 22:31:22 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.021s]
# 10/21/2020 22:31:22 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:22 - INFO - haystack.finder -   Reader is looking for detailed answer in 78651 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.94 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.77 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.78 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 28.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.37 Batches/s]
# 10/21/2020 22:31:27 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.041s]
# 10/21/2020 22:31:27 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:27 - INFO - haystack.finder -   Reader is looking for detailed answer in 67993 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 34.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 37.47 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.51 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 28.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.57 Batches/s]
# 10/21/2020 22:31:31 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.044s]
# 10/21/2020 22:31:31 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:31 - INFO - haystack.finder -   Reader is looking for detailed answer in 71734 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 32.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.12 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.67 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 32.54 Batches/s]
# 10/21/2020 22:31:35 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.028s]
# 10/21/2020 22:31:35 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:35 - INFO - haystack.finder -   Reader is looking for detailed answer in 67424 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 34.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.78 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.51 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.18 Batches/s]
# 10/21/2020 22:31:39 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.026s]
# 10/21/2020 22:31:39 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:39 - INFO - haystack.finder -   Reader is looking for detailed answer in 66165 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.77 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 26.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 36.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.26 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.40 Batches/s]
# 10/21/2020 22:31:43 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.029s]
# 10/21/2020 22:31:43 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:43 - INFO - haystack.finder -   Reader is looking for detailed answer in 58473 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.42 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.62 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.00 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.89 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.31 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.41 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.59 Batches/s]
# 10/21/2020 22:31:47 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:31:47 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:47 - INFO - haystack.finder -   Reader is looking for detailed answer in 67881 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.78 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 42.68 Batches/s]
# 10/21/2020 22:31:50 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.025s]
# 10/21/2020 22:31:50 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:50 - INFO - haystack.finder -   Reader is looking for detailed answer in 77312 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.61 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 26.89 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.19 Batches/s]
# 10/21/2020 22:31:55 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.033s]
# 10/21/2020 22:31:55 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:55 - INFO - haystack.finder -   Reader is looking for detailed answer in 75418 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.16 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.12 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.37 Batches/s]
# 10/21/2020 22:31:59 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.035s]
# 10/21/2020 22:31:59 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:31:59 - INFO - haystack.finder -   Reader is looking for detailed answer in 94024 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 28.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.19 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.26 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 41.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.08 Batches/s]
# 10/21/2020 22:32:04 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.028s]
# 10/21/2020 22:32:04 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:04 - INFO - haystack.finder -   Reader is looking for detailed answer in 54766 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.47 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.91 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.79 Batches/s]
# 10/21/2020 22:32:07 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.018s]
# 10/21/2020 22:32:07 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:07 - INFO - haystack.finder -   Reader is looking for detailed answer in 62857 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.07 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.18 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 43.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.39 Batches/s]
# 10/21/2020 22:32:11 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.018s]
# 10/21/2020 22:32:11 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:11 - INFO - haystack.finder -   Reader is looking for detailed answer in 66775 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.61 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.91 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.51 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.37 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.37 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.61 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.31 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.19 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.63 Batches/s]
# 10/21/2020 22:32:15 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:32:15 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:15 - INFO - haystack.finder -   Reader is looking for detailed answer in 66247 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.54 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 38.71 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.31 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.28 Batches/s]
# 10/21/2020 22:32:19 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.030s]
# 10/21/2020 22:32:19 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:19 - INFO - haystack.finder -   Reader is looking for detailed answer in 67312 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.71 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.67 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  2.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.31 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 26.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.31 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 41.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.96 Batches/s]
# 10/21/2020 22:32:23 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.026s]
# 10/21/2020 22:32:23 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:23 - INFO - haystack.finder -   Reader is looking for detailed answer in 75112 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.12 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 28.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.67 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.54 Batches/s]
# 10/21/2020 22:32:27 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.017s]
# 10/21/2020 22:32:27 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:27 - INFO - haystack.finder -   Reader is looking for detailed answer in 66419 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.59 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.13 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.27 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 35.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.16 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.68 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.09 Batches/s]
# 10/21/2020 22:32:31 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.014s]
# 10/21/2020 22:32:31 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:31 - INFO - haystack.finder -   Reader is looking for detailed answer in 63103 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.37 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.94 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 32.71 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 35.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.52 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 35.77 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.34 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.26 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.04 Batches/s]
# 10/21/2020 22:32:35 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.026s]
# 10/21/2020 22:32:35 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:35 - INFO - haystack.finder -   Reader is looking for detailed answer in 74722 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  2.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.27 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.89 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 26.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.86 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.76 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.29 Batches/s]
# 10/21/2020 22:32:39 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:32:39 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:39 - INFO - haystack.finder -   Reader is looking for detailed answer in 62439 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.27 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 37.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.63 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 43.85 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.73 Batches/s]
# 10/21/2020 22:32:43 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.021s]
# 10/21/2020 22:32:43 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:43 - INFO - haystack.finder -   Reader is looking for detailed answer in 59116 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.19 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.54 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.06 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.89 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.93 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.00 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.19 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.37 Batches/s]
# 10/21/2020 22:32:46 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.022s]
# 10/21/2020 22:32:46 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:32:46 - INFO - haystack.finder -   Reader is looking for detailed answer in 78916 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.57 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.32 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.99 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.00 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.41 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.01 Batches/s]
# ...
# 10/21/2020 22:34:25 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.013s]
# 10/21/2020 22:34:25 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:25 - INFO - haystack.finder -   Reader is looking for detailed answer in 61406 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.24 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.11 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.61 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.67 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.03 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.18 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.47 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.38 Batches/s]
# 10/21/2020 22:34:29 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:34:29 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:29 - INFO - haystack.finder -   Reader is looking for detailed answer in 64816 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.91 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.78 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.72 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.07 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 36.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.27 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.51 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.65 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.09 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.73 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.50 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.40 Batches/s]
# 10/21/2020 22:34:32 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.014s]
# 10/21/2020 22:34:32 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:32 - INFO - haystack.finder -   Reader is looking for detailed answer in 79431 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.44 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.28 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.83 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.87 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.62 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.04 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.10 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.16 Batches/s]
# 10/21/2020 22:34:37 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:34:37 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:37 - INFO - haystack.finder -   Reader is looking for detailed answer in 65597 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.90 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 35.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  2.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.74 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.71 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.07 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.00 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 35.88 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 24.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.11 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 22.59 Batches/s]
# 10/21/2020 22:34:41 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:34:41 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:41 - INFO - haystack.finder -   Reader is looking for detailed answer in 77724 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.17 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.27 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.30 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.64 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 28.94 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.10 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.70 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.29 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.38 Batches/s]
# 10/21/2020 22:34:45 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.009s]
# 10/21/2020 22:34:45 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:45 - INFO - haystack.finder -   Reader is looking for detailed answer in 80331 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.37 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.69 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.14 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 31.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 17.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 12.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 26.63 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 29.48 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.95 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 34.55 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  3.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.22 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 46.53 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.35 Batches/s]
# 10/21/2020 22:34:49 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:34:49 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:49 - INFO - haystack.finder -   Reader is looking for detailed answer in 65385 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.56 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.97 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.92 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.43 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.20 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 33.25 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 27.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.46 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.74 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.40 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 11.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.75 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.51 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 20.48 Batches/s]
# 10/21/2020 22:34:53 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.021s]
# 10/21/2020 22:34:53 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:53 - INFO - haystack.finder -   Reader is looking for detailed answer in 63963 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.05 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.45 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.35 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 15.11 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.89 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.98 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.67 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 25.15 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 18.23 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 16.58 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.38 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.08 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 21.11 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 14.82 Batches/s]
# 10/21/2020 22:34:57 - INFO - elasticsearch -   POST http://localhost:9200/document/_search [status:200 request:0.019s]
# 10/21/2020 22:34:57 - INFO - haystack.retriever.sparse -   Got 20 candidates from retriever
# 10/21/2020 22:34:57 - INFO - haystack.finder -   Reader is looking for detailed answer in 72346 chars ...
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.82 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 23.39 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 10.84 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.21 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.49 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.33 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  7.60 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 30.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.54 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.66 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  9.02 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  6.47 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.81 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  8.36 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.79 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  4.96 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 13.80 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00, 19.01 Batches/s]
# Inferencing Samples: 100%|██████████| 1/1 [00:00<00:00,  5.38 Batches/s]

# %% [markdown]
# # Step 9. Checking whether obtained answers are compatible with our previous knowledge from step 4

# %%
# making a function that get a list of answers, extract unique company names,
#   validate them using company name dataframe, and return partners
def get_partners(answers, model, company_names_df, target_company_name):
  
  partners = []
  for answer in answers:
    doc = model(answer)
    ner_array = np.array([(X.text, X.label_) for X in doc.ents])
    try:
      companies = np.unique(ner_array[np.where(ner_array[:, 1] == 'ORG')[0], 0])
    except Exception as e:
      continue
    for company in companies:
      if company not in partners \
         and company in list(company_names_df.company_name) \
         and company != target_company_name:
          partners.append(company)

  return partners

# %%
for i in range(len(answer_dict_list)):

  partners = get_partners(answer_dict_list[i]['answers'], nlp, company_names_df, 
                          answer_dict_list[i]['company'])
  answer_dict_list[i]['partners'] = partners

# %%
i=3
print('company:', answer_dict_list[i]['company'])
print('partners:', answer_dict_list[i]['partners'])
# Out:
# company: Toyota
# partners: ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']

# %% [markdown]
# :) Seems it's working, we just need to test the results

# %% [markdown]
# # Step 10. Cross-validate the asnwers with itself and test the model results.

# %% [markdown]
# First, let's make a dataframe from the list of dictionaries.

# %%
final_df = pd.DataFrame(answer_dict_list)
final_df.head()
# Out:
#   company  ...                                                                         partners
# 0    Ford  ...  [Changan Automobile Co., Ford Motor Co., Volkswagen Group, Ford Motor, VW, V...
# 1   Tesla  ...  [Contemporary Amperex Technology Co., LG Chem, Panasonic, Panasonic Corp., D...
# 2      GM  ...  [Honda, Chongqing Changan Automobile Co., SAIC, SAIC Motor Corp., Changan Au...
# 3  Toyota  ...  [Amazon, Mazda, Uber, FAW Group, Guangzhou Automobile Group, Mazda Motor Cor...
# 4  Nissan  ...  [Mitsubishi Motors, Renault, Mitsubishi, Renault SA, Mitsubishi Motors Corp....
#
# [5 rows x 3 columns]

# %% [markdown]
# Now, for each company, we would iterate through its obtained partners, make questions about the partner's partners (just like previous steps), if the target company was among partner's partner, we would take it as a 'true positive answer', if it wasn't among them, we would take it as a 'false positive'.
# Finaly, we would measure precision as:
#
#
# ```
# # precision = count of true positives / (count of true positives + count of false positives)
# ```

# %%
def tp_fp_count_calc(company_name, partners, finder_model, company_names_df, 
                     final_df):

  tp = 0
  fp = 0
  
  for partner in partners:
    
    # to decrease computation:
    if len(final_df[final_df['company'] == partner]) != 0:

      partners_of_partner = final_df[final_df['company'] == partner]['partners'].values[0]

    else:

      questions = get_q_list(partner)

      answers = []
      for q in questions:
        prediction = finder.get_answers(question=q, 
                                        top_k_retriever=TOP_K_RETRIEVER_DEFAULT, 
                                        top_k_reader=TOP_K_READER_DEFAULT)
        answers.append([prediction['answers'][k]['answer']
                        for k in range(len(prediction['answers']))])
      answers = list(itertools.chain.from_iterable(answers))
      partners_of_partner = get_partners(answers, nlp, company_names_df, answers)
      final_df = final_df.append({'company': partner, 'answers': answers, 
                                  'partners': partners_of_partner}, ignore_index=True)

    if company_name in partners_of_partner:
      tp += 1
    else:
      fp += 1

  return tp, fp, final_df

# %%
tp_lst, fp_lst, precision_lst = [], [], []

for i in range(final_df.shape[0]):

  tp, fp, final_df = tp_fp_count_calc(final_df.iloc[i, 0], final_df.iloc[i, 2], 
                                      finder, company_names_df, final_df)
  precision = tp / (tp + fp)

  tp_lst.append(tp)
  fp_lst.append(fp)
  precision_lst.append(precision)
# Out:
# ['Ford', 'PSA', 'Peugeot', 'Suzuki', 'Ford Motor Co.', 'Mazda Motor Corp.', 'Changan Automobile Co.', 'Suzuki Motor Corp.', 'Changan', 'GM', 'Mazda', 'FAW', 'Volkswagen']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['FAW', 'SAIC', 'Audi', 'Porsche', 'Volkswagen Group', 'VW', 'AC', 'BMW', 'Daimler', 'EVs', 'Ford', 'VW Group', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen', 'Tata Motors', 'Ford Motor Co.', 'Jianghuai Automobile Co.']
# ['Chongqing Changan Automobile Co.', 'Changan Automobile Co.', 'Audi', 'Porsche', "Volkswagen Group's", 'Ford Motor Co.', 'Lyft', 'BAIC Group', 'Hyundai Motor Co.', 'Ford', 'VW Group', 'Volkswagen Group', 'Magna International', 'Ford Motor', 'VW', 'EV', 'Changan', 'Mahindra', 'Baidu', 'Jiangling Motors Corp.', 'Lincoln']
# ['FAW', 'SAIC', 'FAW Group', 'SAIC Motor', 'Daimler', 'GM', 'Ford', 'Volkswagen', 'Byton', 'Hyundai Motor Co.', 'Tesla', 'Ford Motor Co.', 'Volkswagen AG']
# ['FAW', 'SAIC', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen Group', 'VW', 'China FAW Group Corp.', 'Ford Motor', 'Audi', 'Jianghuai Automobile Co.', 'Volkswagen AG', 'Ford', 'Ford Motor Co.', 'Bentley', 'Porsche', 'SAIC Motor', "Volkswagen Group's", 'Lincoln', 'GM', 'Toyota', 'FAW Group', 'FCA']
# ['SAIC Motor Corp.', 'General Motors', 'SAIC Motor', 'GM', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'SAIC', 'Ford', 'Volkswagen']
# ['FCA', 'Mitsubishi Motors Corp.', 'Mitsubishi', 'Renault', 'Nissan Motor Co.', 'Nissan', 'Microsoft', 'Dongfeng Motor Group', 'Mitsubishi Motors', 'Dongfeng', 'Ford', 'GM']
# ["Nissan Motor Co.'s", 'BMW', 'Honda', 'Nissan', 'Dongfeng', 'Dongfeng Motor Corp.', 'Baojun', 'Ford', 'Alliance Ventures']
# ['PSA', 'Suzuki', 'Changan', 'Ford Motor', 'Mazda', 'Mazda Motor Corp.', 'Suzuki Motor Corp.', 'Ford Motor Co.', 'FAW', 'Peugeot', 'Changan Automobile Co.', 'NextEV', 'Nio', 'Citroen', 'Ford', 'Baidu Inc.']
# ['BAIC Motor Group Co.', 'Dongfeng Motor Corp.', 'SAIC Motor Corp.', 'Zhejiang Geely Holding Group Co.', 'Daimler', 'BMW AG', 'Geely Automobile Holdings', 'Toyota', 'LG Chem', 'SK Innovation', 'Daimler AG', 'Nissan Motor Co.', 'the Volkswagen Group', 'Contemporary Amperex Technology', 'EV', 'BAIC Motor Corp.', 'Tesla Inc.', 'Volkswagen AG', 'BMW Group', 'Geely', 'Toyota Motor Corp.', 'Volkswagen Group', 'Mazda', 'Panasonic', 'Panasonic Corp.', 'Subaru']
# ['Nissan', 'VW', 'General Motors', 'Tesla Inc.', 'Geely Automobile Holdings', 'Volkswagen Group', 'Renault', 'Ford', 'GM', 'Volkswagen', 'Ford Motor Co.', 'Volkswagen AG', 'LG Chem', 'Tesla', 'Volvo Cars', 'Samsung', 'Contemporary Amperex Technology', 'EV', 'CATL', 'Panasonic', 'Chery Automobile Co.', 'China FAW Group Corp.', 'Chongqing Changan Automobile Co.', 'Great Wall Motor Co.', 'Apple Inc.', 'Panasonic Corp.']
# ['Tesla', 'Denso Corp.', 'Panasonic', 'Hitachi', 'Toyota', 'Panasonic Corp.', 'Toyota Motor Corp.', 'Honda', 'Ford Motor Co.']
# ['Ford Motor Co.', 'Toyota Motor Corp.', 'Tesla', 'Toyota', 'Denso Corp.', 'Contemporary Amperex Technology Co.', 'LG Chem', 'Panasonic', 'Hitachi', 'Volkswagen', 'CATL', 'Panasonic Corp.']
# ['SoftBank', 'Toyota', 'the University of Michigan', 'Denso', 'Toyota Motor', 'Aisin Seiki', 'Denso Corp.', 'Toyota Motor Corp.', 'Panasonic', 'Bosch', 'Continental AG', 'Audi', 'BMW AG', 'Daimler AG']
# ['Acura', 'Honda', 'Volkswagen', 'Apple', 'Mercedes-Benz', 'Tesla', 'Apple Inc.', 'Google', 'BMW AG', 'Volkswagen AG', 'Ford Motor Co.', 'Tesla Inc.', 'General Motors', 'Bosch', 'AT&T']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['Nvidia', 'Qualcomm', 'BMW', 'Delphi', 'Intel', 'Daimler', 'Geely', 'Nissan', 'Volkswagen', 'BMW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Continental', 'Baidu', 'Valeo', 'Aptiv', 'Waymo', 'Volkswagen Group']
# ['Uber', 'Volkswagen', 'SF Motors', 'Singulato Motors', 'Volkswagen AG', 'Intel', 'BMW', 'Delphi', 'Audi', 'Bosch', 'Mercedes-Benz', 'Tesla', 'Volvo', 'Autoliv', 'Hella', 'Toyota Motor Corp.', 'Volkswagen Group', 'Nvidia', 'AB Volvo', 'SAIC', 'Aurora', 'Baidu', 'Harman', 'Panasonic', 'Hyundai']
# ['Mazda', 'Toyota', 'Volkswagen', 'Changan Automobile Co.', 'Honda', 'Nissan', 'FAW Group', 'VW', 'Ford', 'FAW', 'Daimler', 'Toyota Motor', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'FAW-VW', 'the Volkswagen Group', 'General Motors']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'GM', 'Changan Automobile Co.', 'Volkswagen Group', 'VW', 'Daimler', 'General Motors Co.', 'Toyota Motor Corp.']
# ['Apple', 'Mercedes-Benz', 'Acura', 'Honda', 'Volkswagen', 'Tesla', 'Google', 'AT&T', 'Ford Motor Co.', 'Continental AG', 'Daimler', 'Porsche', 'Tesla Inc.', 'J.D. Power', 'Aurora Innovation', 'VW', 'Apple Inc.', 'Fiat Chrysler Automobiles', 'Lyft Inc.', 'General Motors']
# ['Bosch', 'Continental', 'Ford Motor Co.', 'General Motors', 'Mcity', 'Toyota Motor Corp.', 'Google', 'Audi', 'Fiat', 'Apple', 'Amazon', 'Chrysler', 'Fiat Chrysler', 'Ford', 'Mitsubishi', 'Nissan', 'Renault', 'AutoNation', 'Walmart', 'Honda', 'Hyundai']
# ['BMW', 'Nissan', 'Waymo', 'Changan Automobile Co.', 'Isuzu', 'GM', 'Daimler', 'Hyundai', 'Toyota', 'General Motors', 'EV', 'AutoNation', 'Fiat Chrysler', 'Jaguar Land Rover']
# ['Ford', 'PSA', 'Peugeot', 'Suzuki', 'Changan', 'Mazda', 'Ford Motor Co.', 'Mazda Motor Corp.', 'Suzuki Motor Corp.', 'Dongfeng', 'Renault', 'Citroen']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'Volkswagen Group', 'GM', 'Wuling', 'Buick', 'Cadillac', 'Chevrolet', 'the Volkswagen Group', 'Suzuki Motor Corp.', 'General Motors Co.']
# ['General Motors', 'Volkswagen', 'GM', 'Volkswagen Group', 'SAIC', 'Changan Automobile Co.', 'SAIC Motor Corp.', 'Daimler', 'the Volkswagen Group']
# ['Ford', 'PSA', 'Peugeot', 'Suzuki', 'Ford Motor Co.', 'Mazda Motor Corp.', 'Changan Automobile Co.', 'Suzuki Motor Corp.', 'Changan', 'GM', 'Mazda', 'FAW', 'Volkswagen']
# ['Nissan', 'VW', 'General Motors', 'Tesla Inc.', 'Geely Automobile Holdings', 'Volkswagen Group', 'Renault', 'Ford', 'GM', 'Volkswagen', 'Ford Motor Co.', 'Volkswagen AG', 'LG Chem', 'Tesla', 'Volvo Cars', 'Samsung', 'Contemporary Amperex Technology', 'EV', 'CATL', 'Panasonic', 'Chery Automobile Co.', 'China FAW Group Corp.', 'Chongqing Changan Automobile Co.', 'Great Wall Motor Co.', 'Apple Inc.', 'Panasonic Corp.']
# ['Daimler', 'Volkswagen', 'LG Chem', 'Honda Motor Co.', 'Nikola Corp.', 'GM', 'Honda', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'Geely', 'Geely Automobile', 'Hyundai Motor Co.', 'Toyota Motor Corp.', 'Volkswagen Group', 'EVgo', 'General Motors', 'Ford', 'Ford Motor Co.', 'Magna International']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['Bosch', 'Continental', 'Ford Motor Co.', 'General Motors', 'Mcity', 'Toyota Motor Corp.', 'Google', 'Audi', 'Fiat', 'Apple', 'Amazon', 'Chrysler', 'Fiat Chrysler', 'Ford', 'Mitsubishi', 'Nissan', 'Renault', 'AutoNation', 'Walmart', 'Honda', 'Hyundai']
# ['Guangzhou Automobile Group Co.', 'Ford', 'VW', 'Chrysler', 'Jeep', 'Fiat Chrysler', 'Volkswagen AG', 'Fiat Chrysler Automobiles', 'Guangzhou Automobile Group', 'Aurora Innovation', 'PSA Group', 'BAIC Group', 'Renault', 'Chevrolet', 'Mitsubishi', 'Nissan', 'Fiat']
# ['Jaguar', 'Waymo', 'Rover', 'BMW Group', 'Zhejiang Geely Holding', 'Chery', 'General Motors Co.', 'BMW', 'Jaguar Land Rover', 'Ford', 'Bentley', 'Ford Motor Co.', 'Tata Motors']
# ['AutoNation', 'Daimler', 'Delphi', 'Ford', 'Intel', 'Microsoft', 'Nissan', 'Renault', 'Fiat', 'Lyft', 'Waymo', 'Honda', 'Jaguar', 'Fiat Chrysler Automobiles', 'Jaguar Land Rover', 'Walmart', 'FCA', 'JLR']
# ['Ford', 'GM', 'Honda Motor Co.', 'Volvo', 'Uber Technologies', 'Aptiv', 'Panasonic Corp.', 'Amazon', 'Mazda', 'Uber', 'fintech', 'Volkswagen']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['GM', 'LG Chem', 'AT&T', 'Amazon', 'Google', 'Michelin', 'Changan Automobile Co.', 'Omnicom', 'General Motors', 'Honda', 'Ford', 'Lyft', 'Hyundai', 'Nissan']
# ['Omnicom', 'Dentsu', 'WPP', 'Ford']
# ['Ford', 'GM', 'Honda Motor Co.', 'Volvo', 'Uber Technologies', 'Aptiv', 'Panasonic Corp.', 'Amazon', 'Mazda', 'Uber', 'fintech', 'Volkswagen']
# ['Ford Motor Co.', 'Toyota', 'Toyota Motor Corp.', 'Mazda', 'TMCC', 'Chase', 'Mazda Motor Corp.', 'Mazda3', 'Nissan']
# ['Daimler', 'Volvo', 'Toyota', 'Uber', 'SoftBank', 'General Motors Co.', 'SoftBank Group Corp.', 'Waymo', 'Toyota Motor Corp.', 'Volkswagen AG', 'Goldman Sachs', 'General Motors', 'Santander Consumer USA Holdings Inc.', 'Amazon', 'Apple', 'Google']
# ['Mazda', 'Toyota', 'Volkswagen', 'Changan Automobile Co.', 'Honda', 'Nissan', 'FAW Group', 'VW', 'Ford', 'FAW', 'Daimler', 'Toyota Motor', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'FAW-VW', 'the Volkswagen Group', 'General Motors']
# ['Honda', 'Mitsubishi Motors', 'Toyota', 'Honda Motor Co.', 'Toyota Motor Corp.', 'BAIC Group', 'Fiat Chrysler Automobiles', 'Changan Automobile Co.', 'Tencent Holdings', 'FCA', 'Fiat Chrysler', 'FAW', 'Guangzhou Automobile Group', 'Fiat', 'GAC', 'Mitsubishi Motors Corp.', 'General Motors', 'Volkswagen AG']
# ['China FAW Group Corp.', 'Toyota', 'Toyota Motor Corp.', 'Toyota Financial Services', 'Mazda Motor Corp.', 'Mazda', 'Subaru', 'Suzuki', 'Panasonic', 'Denso Corp.']
# ['Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'Toyota', 'Fiat', 'Honda', 'FCA', 'the National Automobile Dealers Association', 'Chrysler', 'Guangzhou Automobile Group', 'Mitsubishi Motors', 'GAC', 'Mitsubishi', 'Fiat Chrysler']
# ['Honda', 'Nissan', 'PSA', 'Peugeot', 'Honda Motor Co.', 'Nissan Motor Co.', 'Renault', 'Kia', 'Kia Motors Corp.', 'Dongfeng', 'Suzuki', 'Honda Motor', 'Kia Motors', 'Nissan Motor', 'PSA Group', 'Dongfeng Motor Corp.', "General Motors'", 'SAIC Motor', 'Renault SA']
# ['Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'Ford Motor Co.', 'General Motors', 'Tencent Holdings', 'Changan Automobile Co.', 'BMW', 'Geely', 'SAIC', 'Honda', 'Mitsubishi Motors', 'Toyota', 'FCA', 'Fiat']
# ['SoftBank', 'Toyota', 'the University of Michigan', 'Denso', 'Toyota Motor', 'Aisin Seiki', 'Denso Corp.', 'Toyota Motor Corp.', 'Panasonic', 'Bosch', 'Continental AG', 'Audi', 'BMW AG', 'Daimler AG']
# ['BMW', 'Daimler', 'Ford', 'VW Group', 'VW', 'BMW Group', 'Ford Motor Co.', 'Audi', 'Porsche', "Volkswagen Group's", 'SAIC Motor Corp.', 'Changan Automobile Co.', 'FAW Group', 'GAC', 'Guangzhou Automobile Group', 'EVgo', 'General Motors', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'China FAW Group Corp.', 'EV', 'Denso Corp.', 'EVs', 'Mazda Motor Corp.', 'Toyota Motor Corp.', 'Nio', 'Mitsubishi', 'Renault', 'Magna International']
# ['FAW Group', 'Guangzhou Automobile Group', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'GAC', 'Denso Corp.', 'Mazda Motor Corp.', 'Apple', 'Tesla', 'Denso', 'Mazda', 'Subaru', 'Suzuki', 'Panasonic', 'FAW', 'Fuji Heavy Industries', 'Toyota Motor Corp.', 'Honda', 'Nissan', 'Toyota']
# ['Toyota Motor Corp.', 'Mazda Motor Corp.', 'Subaru', 'Fuji Heavy Industries', 'Chery Automobile Co.', 'Honda Motor Co.', 'Fuji Heavy', 'Toyota', 'Mitsubishi Motors', 'Mazda', 'Daimler', 'Ford', 'Nissan', 'Subaru of America']
# ['Mazda Motor Corp.', 'Panasonic Corp.', 'Isuzu', 'Subaru', 'Toyota', 'Mazda', 'Suzuki', 'Ford Motor Co.', 'General Motors', 'Nissan Motor Co.', 'Toyota Motor', 'Daihatsu', 'Suzuki Motor Corp.', 'Fuji Heavy Industries', 'Subaru of America', 'Hitachi']
# ['General Motors Co.', 'VW', 'Mazda', 'Subaru', 'Suzuki', 'Volkswagen', 'Suzuki Motor Corp.', 'Volkswagen AG', 'Changan', 'Toyota Motor Corp.', 'Honda Motor Co.', 'General Motors', 'Tata Motors']
# ['Tesla', 'Denso Corp.', 'Panasonic', 'Hitachi', 'Toyota', 'Panasonic Corp.', 'Toyota Motor Corp.', 'Honda', 'Ford Motor Co.']
# ['Acura', 'Honda', 'Volkswagen', 'Apple', 'Mercedes-Benz', 'Tesla', 'Apple Inc.', 'Google', 'BMW AG', 'Volkswagen AG', 'Ford Motor Co.', 'Tesla Inc.', 'General Motors', 'Bosch', 'AT&T']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Renault SA']
# ['Fiat', 'PSA', 'PSA Group', 'BMW', 'Daimler', 'Ford', 'Citroen', 'Peugeot', 'General Motors', 'Toyota', 'Dongfeng Motor Group']
# ['Dongfeng Motor Group', 'PSA', 'Peugeot', 'Mitsubishi', 'Nissan', 'Citroen', 'Renault', 'Fiat Chrysler', 'Dongfeng Motor Corp.', 'BMW', 'Ford', 'Dongfeng', 'LG Chem']
# ['FAW', 'SAIC', 'Audi', 'Porsche', 'Volkswagen Group', 'VW', 'AC', 'BMW', 'Daimler', 'EVs', 'Ford', 'VW Group', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen', 'Tata Motors', 'Ford Motor Co.', 'Jianghuai Automobile Co.']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Renault SA', 'Mitsubishi', 'Mitsubishi Motors', 'Chrysler', 'Dongfeng']
# ['Mitsubishi', 'Nissan', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Dongfeng', 'Renault', 'Ghosn', 'Mitsubishi Motors']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Renault SA']
# ['Mitsubishi', 'Nissan', 'Renault', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Fiat', 'Renault SA', 'Dongfeng', 'BMW AG', 'Volkswagen AG']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Mitsubishi Motors', 'Chrysler', 'Mitsubishi Motors Corp.', 'GAC', 'Renault SA', 'Alliance']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Mitsubishi Motors Corp.', 'Microsoft', 'Nissan', 'Infiniti', 'Nissan Motor Co.', 'Dongfeng Motor Group', 'Toyota', 'Volkswagen', 'Renault SA', 'FCA', 'Audi AG', 'Mercedes-Benz', 'Hertz']
# ['Renault', 'Amazon', 'Google', 'Toyota', 'Volvo', 'Continental AG', 'Daimler AG', 'Ford Motor Co.', 'Mitsubishi Electric', 'Daimler', 'Delphi', 'Ford', 'Intel', 'Microsoft', 'BMW Group', 'CDK', 'Fortellis', 'BMW', 'Harman', 'Aptiv', 'Bosch', 'Denso', 'General Motors Co.', 'Honda Motor Co.', 'Hyundai Motor Co.', 'Nissan']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi AG', 'Daimler AG', 'the European Union', 'Ford Motor Co.', 'BMW', 'Ford', 'VW', 'BMW AG', 'Volkswagen AG', 'Brilliance China Automotive Holdings', 'Toyota Motor Corp.', 'Fiat', 'Toyota', 'General Motors', 'Audi', 'Daimler', 'Apple Inc.', 'Aptiv', 'Continental', 'Delphi', 'Intel', 'Mercedes', 'DriveNow', 'Volkswagen', 'Fiat Chrysler', 'Renault', 'Nissan']
# ['BMW', 'Continental', 'Fiat', 'Intel', 'Chrysler', 'Goldman Sachs', 'Samsung', 'Delphi', 'Denso', 'BorgWarner', 'Delphi Automotive', 'Aptiv', 'Barclays', 'Valeo']
# ['BAIC Group', 'Fiat Chrysler Automobiles', 'BMW Group', 'Intel', 'Ferrari', 'Fiat Chrysler', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Mitsubishi', 'Nissan', 'Ford Motor Co.', 'GM', 'BMW AG', 'Delphi Automotive', 'Intel Corp.', 'PSA Group', 'BMW', 'Continental', 'Delphi', 'Aurora', 'Guangzhou Automobile Group', 'Aurora Innovation', 'Google', 'Fiat', 'Renault', 'Guangzhou Automobile Group Co.', 'Ford', 'Peugeot']
# ['Intel', 'Nvidia', 'Qualcomm', 'Continental', 'Delphi', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Daimler', 'Geely', 'Audi', 'Mercedes', 'Volvo', 'Baidu', 'Valeo', 'BMW', 'BMW Group', 'Nio Inc.', 'Apple Inc.', 'Aptiv', 'Waymo', 'Tencent']
# ['Apple Inc.', 'FAW', 'Volkswagen', 'Porsche', "Volkswagen Group's", 'BMW', 'Daimler', 'AT&T', 'VW', 'SAIC', 'Ford Motor Co.', 'AutoGravity', 'Audi AG', 'General Motors', 'Hyundai', 'Continental', 'Jeep', 'Mercedes-Benz', 'FAW Group', 'VW Group', 'Apple', 'Google', 'Toyota']
# ['Nvidia', 'Qualcomm', 'BMW', 'Delphi', 'Intel', 'Daimler', 'Geely', 'Nissan', 'Volkswagen', 'BMW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Continental', 'Baidu', 'Valeo', 'Aptiv', 'Waymo', 'Volkswagen Group']
# ['Daimler', 'GM', 'VW', 'Baidu', 'Audi AG', 'BMW AG', 'Daimler AG', 'Audi', 'BMW', 'Mercedes-Benz', 'FAW', 'SAIC Motor', 'Ford Motor Co.', 'General Motors', 'TK Holdings Inc.', 'SAIC', 'SAIC Motor Corp.', 'Volkswagen', 'China FAW Group Corp.', 'Volkswagen AG', 'Bentley', 'Porsche', 'Apple Inc.', 'Nissan Motor', 'Renault']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['Mitsubishi', 'Renault', 'Daimler', 'Ford Motor Co.', 'General Motors', 'Renault-Nissan', 'Baidu', 'Continental', 'Delphi', 'Bosch', 'BAIC Group', 'GAC Motor', 'SK Innovation', 'Great Wall Motor Co.', 'Nvidia', 'Audi', 'Continental AG', 'Nexteer', 'Intel']
# ['BMW', 'Continental', 'Fiat', 'Intel', 'Chrysler', 'Goldman Sachs', 'Samsung', 'Delphi', 'Denso', 'Delphi Automotive', 'Intel Corp.', 'NuTonomy', 'GM', 'Treasury']
# ['Audi', 'Daimler', 'BMW Group', 'Intel', 'BMW', 'Ford', 'VW Group', 'Ford Motor Co.', 'Porsche', "Volkswagen Group's", 'Audi AG', 'Chongqing Changan Automobile Co.', 'Continental', 'Delphi', 'Fiat Chrysler Automobiles', 'Nissan', 'Renault', 'Apple', 'Google', 'Volkswagen Group', 'DriveNow']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Renault SA', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Microsoft']
# ['Mitsubishi', 'Nissan', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Dongfeng', 'Renault', 'Ghosn', 'Mitsubishi Motors']
# ['Apple', 'Mercedes-Benz', 'Acura', 'Honda', 'Volkswagen', 'Tesla', 'Google', 'AT&T', 'Ford Motor Co.', 'Continental AG', 'Daimler', 'Porsche', 'Tesla Inc.', 'J.D. Power', 'Aurora Innovation', 'VW', 'Apple Inc.', 'Fiat Chrysler Automobiles', 'Lyft Inc.', 'General Motors']
# ['Bosch', 'Continental', 'Ford Motor Co.', 'General Motors', 'Mcity', 'Toyota Motor Corp.', 'Google', 'Audi', 'Fiat', 'Apple', 'Amazon', 'Chrysler', 'Fiat Chrysler', 'Ford', 'Mitsubishi', 'Nissan', 'Renault', 'AutoNation', 'Walmart', 'Honda', 'Hyundai']
# ['BMW', 'Daimler', 'Mercedes-Benz Financial Services', 'Daimler AG', 'Nissan', 'BAIC Motor Corp.', 'Mercedes', 'Baidu', 'AutoGravity', 'Mercedes-Benz', 'Audi', 'VW Group', 'Porsche', 'Apple', 'Google']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['Toyota Motor', 'China FAW Group Corp.', 'VW', 'Changan Automobile Co.', 'FAW Group', 'Mazda', 'Toyota', 'Volkswagen', 'FAW', 'Daimler', 'Honda', 'Nissan', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'the Volkswagen Group', 'FAW-VW', 'Mazda Motor Corp.']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'Volkswagen Group', 'GM', 'Wuling', 'Buick', 'Cadillac', 'Chevrolet', 'the Volkswagen Group', 'Suzuki Motor Corp.', 'General Motors Co.']
# ['Mazda', 'Toyota', 'Volkswagen', 'Changan Automobile Co.', 'Honda', 'Nissan', 'FAW Group', 'VW', 'Ford', 'FAW', 'Daimler', 'Toyota Motor', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'FAW-VW', 'the Volkswagen Group', 'General Motors']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'GM', 'Changan Automobile Co.', 'Volkswagen Group', 'VW', 'Daimler', 'General Motors Co.', 'Toyota Motor Corp.']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['FAW', 'SAIC', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen Group', 'VW', 'China FAW Group Corp.', 'Ford Motor', 'Audi', 'Jianghuai Automobile Co.', 'Volkswagen AG', 'Ford', 'Ford Motor Co.', 'Bentley', 'Porsche', 'SAIC Motor', "Volkswagen Group's", 'Lincoln', 'GM', 'Toyota', 'FAW Group', 'FCA']
# ['Bosch', 'Byton', 'FAW Group', 'China FAW Group Corp.', 'Contemporary Amperex Technology', 'EV', 'Contemporary Amperex Technology Co.', 'Tesla', 'Volkswagen Group', 'Amazon', 'BlackBerry', 'Intel', 'Qualcomm', 'Foxconn', 'Tencent']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'Kia', 'BMW', 'Daimler', 'Hyundai Motor', 'Aptiv', 'Hyundai', 'Pony.ai', 'Dongfeng Motor Group', 'Dongfeng Motor Corp.', 'BAIC Group', 'Hertz', 'Kia Motors']
# ['Contemporary Amperex Technology Co.', 'LG Chem', 'Panasonic', 'Panasonic Corp.', 'Denso Corp.', 'Apple Inc.', 'Toyota', 'Intel', 'Nvidia', 'FAW Group', 'SAIC Motor', 'Apple', 'Google']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['FAW', 'SAIC', 'SAIC Motor', 'Ford Motor Co.', 'General Motors Co.', 'Toyota Motor Corp.', 'Volkswagen AG', 'VW', 'China FAW Group Corp.', 'Jianghuai Automobile Co.', 'Volkswagen', 'Audi', 'SAIC Motor Corp.', 'Daimler AG', 'Volvo', 'Bentley', 'Porsche', 'Apple Inc.', 'Scania', 'Ford', 'Lincoln', 'BMW AG', 'Toyota']
# ['Audi', 'Daimler', 'BMW Group', 'Intel', 'BMW', 'Ford', 'VW Group', 'Ford Motor Co.', 'Porsche', "Volkswagen Group's", 'Audi AG', 'Chongqing Changan Automobile Co.', 'Continental', 'Delphi', 'Fiat Chrysler Automobiles', 'Nissan', 'Renault', 'Apple', 'Google', 'Volkswagen Group', 'DriveNow']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['FAW', 'SAIC', 'SAIC Motor', 'FAW Group', 'Daimler', 'GM', 'VW', 'Ford', 'Volkswagen', 'BMW', 'Audi', 'Porsche', 'Apple', 'Google']
# ['FAW', 'SAIC', 'FAW Group', 'SAIC Motor', 'Daimler', 'GM', 'Ford', 'Volkswagen', 'Byton', 'Hyundai Motor Co.', 'Tesla', 'Ford Motor Co.', 'Volkswagen AG']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'BMW', 'Daimler', 'European Union', 'BMW Group', 'Kia', 'Pony.ai', 'Dongfeng Motor Corp.', 'AutoGravity', 'Aurora', 'EV', 'Fiat', 'CDK Global', 'Honda', 'Nissan', 'Toyota', 'Tencent Holdings', 'General Motors', 'Nvidia', 'Volkswagen']
# ['Jaguar', 'Waymo', 'Rover', 'BMW Group', 'Zhejiang Geely Holding', 'Chery', 'General Motors Co.', 'BMW', 'Jaguar Land Rover', 'Ford', 'Bentley', 'Ford Motor Co.', 'Tata Motors']
# ['BMW', 'Ford', 'Rover', 'Jaguar', 'Nissan', 'Tata Motors', 'Chery', 'Jiangling Motors Corp.', 'Jaguar Land Rover', 'Chery Automobile Co.', 'Michelin', 'Audi', 'Porsche']
# ['Pininfarina', 'Mahindra & Mahindra', 'Ford Motor Co.', 'Nissan', 'Toyota', 'Mahindra', 'Ford', 'SUV', 'Honda Motor Co.', 'Toyota Motor Corp.']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Renault SA', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Microsoft']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['BAIC Group', 'Fiat Chrysler Automobiles', 'BMW Group', 'Intel', 'Ferrari', 'Fiat Chrysler', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Mitsubishi', 'Nissan', 'Ford Motor Co.', 'GM', 'BMW AG', 'Delphi Automotive', 'Intel Corp.', 'PSA Group', 'BMW', 'Continental', 'Delphi', 'Aurora', 'Guangzhou Automobile Group', 'Aurora Innovation', 'Google', 'Fiat', 'Renault', 'Guangzhou Automobile Group Co.', 'Ford', 'Peugeot']
# ['Beijing Auto', 'GAC', 'General Motors', 'Honda', 'Changan Automobile Co.', 'Apple', 'Google', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'China FAW Group Corp.', 'Eclipse Cross', 'Mitsubishi', 'Nissan Motor Co.', 'Outlander', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Isuzu', 'EV', 'GM', 'AutoNation', 'Fiat Chrysler', 'Jaguar Land Rover', 'Dongfeng', 'Kia Motors Corp.', 'PSA', 'Peugeot', 'FAW', 'Nissan', 'Tesla']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Mitsubishi Motors', 'Chrysler', 'Mitsubishi Motors Corp.', 'GAC', 'Renault SA', 'Alliance']
# ['FAW Group', 'Guangzhou Automobile Group', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'GAC', 'Denso Corp.', 'Mazda Motor Corp.', 'Apple', 'Tesla', 'Denso', 'Mazda', 'Subaru', 'Suzuki', 'Panasonic', 'FAW', 'Fuji Heavy Industries', 'Toyota Motor Corp.', 'Honda', 'Nissan', 'Toyota']
# ['Toyota Motor', 'China FAW Group Corp.', 'VW', 'Changan Automobile Co.', 'FAW Group', 'Mazda', 'Toyota', 'Volkswagen', 'FAW', 'Daimler', 'Honda', 'Nissan', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'the Volkswagen Group', 'FAW-VW', 'Mazda Motor Corp.']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'Volkswagen Group', 'GM', 'Wuling', 'Buick', 'Cadillac', 'Chevrolet', 'the Volkswagen Group', 'Suzuki Motor Corp.', 'General Motors Co.']
# ['Mazda', 'Toyota', 'Volkswagen', 'Changan Automobile Co.', 'Honda', 'Nissan', 'FAW Group', 'VW', 'Ford', 'FAW', 'Daimler', 'Toyota Motor', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'FAW-VW', 'the Volkswagen Group', 'General Motors']
# ['Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'Toyota', 'Fiat', 'Honda', 'FCA', 'the National Automobile Dealers Association', 'Chrysler', 'Guangzhou Automobile Group', 'Mitsubishi Motors', 'GAC', 'Mitsubishi', 'Fiat Chrysler']
# ['Honda', 'Mitsubishi Motors', 'Toyota', 'Honda Motor Co.', 'Toyota Motor Corp.', 'BAIC Group', 'Fiat Chrysler Automobiles', 'Changan Automobile Co.', 'Tencent Holdings', 'FCA', 'Fiat Chrysler', 'FAW', 'Guangzhou Automobile Group', 'Fiat', 'GAC', 'Mitsubishi Motors Corp.', 'General Motors', 'Volkswagen AG']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['FAW', 'SAIC', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen Group', 'VW', 'China FAW Group Corp.', 'Ford Motor', 'Audi', 'Jianghuai Automobile Co.', 'Volkswagen AG', 'Ford', 'Ford Motor Co.', 'Bentley', 'Porsche', 'SAIC Motor', "Volkswagen Group's", 'Lincoln', 'GM', 'Toyota', 'FAW Group', 'FCA']
# ['Fiat Chrysler', 'GM', 'Nissan Motor Co.', 'Volkswagen', 'BMW AG', 'Daimler AG', 'BMW', 'Daimler', 'Mercedes-Benz', 'VW', 'Nissan', 'Chevrolet', 'ChargePoint', 'EVgo', 'Siemens']
# ['ChargePoint', 'Honda Motor Co.', 'LG Chem', 'GM', 'Nikola', 'BMW', 'Nissan', 'Daimler', 'Ford', 'Volkswagen', 'EV', 'EVgo', 'General Motors', 'Audi', 'VW', 'Mitsubishi', 'Renault', 'Ford Motor Co.']
# ['Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi AG', 'Daimler AG', 'the European Union', 'Ford Motor Co.', 'BMW', 'Ford', 'VW', 'BMW AG', 'Volkswagen AG', 'Brilliance China Automotive Holdings', 'Toyota Motor Corp.', 'Fiat', 'Toyota', 'General Motors', 'Audi', 'Daimler', 'Apple Inc.', 'Aptiv', 'Continental', 'Delphi', 'Intel', 'Mercedes', 'DriveNow', 'Volkswagen', 'Fiat Chrysler', 'Renault', 'Nissan']
# ['Microsoft', 'Daimler', 'BAIC Motor Corp.', 'Daimler AG', 'Chongqing Changan Automobile Co.', 'Renault', "Daimler AG's", 'Nissan Motor Co.', 'Renault SA', 'Qualcomm', 'Baidu', 'BMW', 'Nissan', 'Apple Inc.', "Honda Motor Co.'s", 'Toyota Motor Corp.', 'Nissan Motor', 'Fiat Chrysler', 'Ford Motor Co.', 'Volkswagen Group', 'BMW AG']
# ['GM', 'SAIC', 'Changan Automobile Co.', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'General Motors Co.', 'Lyft', 'Michelin', 'Daimler', 'EV', 'Nikola', 'Audi AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Tesla', 'Ford', 'PSA Group', 'Nissan', 'Ford Motor Co.']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Mitsubishi Motors Corp.', 'Microsoft', 'Nissan', 'Infiniti', 'Nissan Motor Co.', 'Dongfeng Motor Group', 'Toyota', 'Volkswagen', 'Renault SA', 'FCA', 'Audi AG', 'Mercedes-Benz', 'Hertz']
# ['Tesla', 'Denso Corp.', 'Panasonic', 'Hitachi', 'Toyota', 'Panasonic Corp.', 'Toyota Motor Corp.', 'Honda', 'Ford Motor Co.']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['Mazda', 'Toyota', 'Volkswagen', 'FAW', 'Volkswagen Group', 'Daimler', 'General Motors', 'Toyota Motor Corp.', 'FAW Group', 'Guangzhou Automobile Group', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'BMW', 'VW', 'Dongfeng Motor Group', 'Volkswagen AG', 'SAIC Motor', 'SAIC', 'Honda', 'Kia', 'Nissan', 'PSA', 'Peugeot']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Renault SA']
# ['Mitsubishi', 'Nissan', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Dongfeng', 'Renault', 'Ghosn', 'Mitsubishi Motors']
# ['BMW', 'Daimler', 'Jaguar Land Rover', 'BAIC Group', 'Magna International Inc.', 'Beijing Auto', 'Magna International', 'Singulato Motors', 'Singulato', 'Bosch', 'Continental']
# ['WM Motor', 'Nissan', 'Renault', 'Alliance Ventures', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'Mitsubishi', 'Mitsubishi Motors', 'Daimler AG', 'Daimler', 'GM', 'General Motors', 'Honda', 'Ultium', 'Toyota', 'Volkswagen Group', 'Dongfeng']
# ['Nissan Motor Acceptance Corp.', 'Cox Automotive', 'CDK', 'Reynolds', 'Electrify America', 'Lyft', 'Ford', 'GM', 'Dealertrack', 'Autotrader', "Cox Automotive's", 'Clutch Technologies', 'Ford Motor Co.']
# ['Omnicom', 'Dentsu', 'WPP', 'Ford']
# ['GTB', 'Omnicom', 'WPP', 'FCA US', 'Ford Motor Co.', 'Ford', 'Mitsubishi', 'Renault']
# ['Fiat', 'PSA', 'PSA Group', 'BMW', 'Daimler', 'Ford', 'Citroen', 'Peugeot', 'General Motors', 'Toyota', 'Dongfeng Motor Group']
# ['General Motors Co.', 'VW', 'Mazda', 'Subaru', 'Suzuki', 'Volkswagen', 'Suzuki Motor Corp.', 'Volkswagen AG', 'Changan', 'Toyota Motor Corp.', 'Honda Motor Co.', 'General Motors', 'Tata Motors']
# ['Geely', 'Daimler', 'Intel', 'Toyota Motor Corp.', 'BMW', 'Tencent Holdings', 'Uber', 'Volvo', 'Toyota', 'Lotus', 'Geely Automobile Holdings', 'LEVC', 'Volvo Cars']
# ['Amazon', 'Google', 'Geely', 'JM&A Group', 'Zhejiang Geely Holding Group', 'Lynk & CO', 'Ford', 'VW', 'AB Volvo', 'Daimler', 'Nvidia', 'Tesla', 'Hyundai Motor Co.', 'ABB', 'Audi', 'BMW', 'Mercedes', 'Zhejiang Geely Holding']
# ['Amazon', 'Google', 'Citigroup Inc.', 'Goldman Sachs Group Inc.', 'Morgan Stanley', 'JM&A Group', 'Geely', 'Volvo', 'China FAW Group Corp.', 'FAW', 'Volkswagen Group', 'Ford', 'VW', 'Hyundai Motor Co.', 'AutoNation', 'Fiat Chrysler Automobiles', 'Jaguar Land Rover', 'Aurora Innovation', 'Intel Corp.', 'Zhejiang Geely Holding Group', 'Dongfeng', 'Renault']
# ['Citigroup Inc.', 'Goldman Sachs Group Inc.', 'Morgan Stanley', 'Volvo', 'Geely Auto', 'Ford Motor Co.', 'General Motors', 'Lynk & CO', 'BMW Group', 'Daimler', 'Volkswagen Group', 'BMW', 'Geely', 'Toyota Motor Corp.', 'Volvo Car Corp.', 'Geely Automobile', 'BMW AG', 'Daimler AG']
# ['Ford', 'Chrysler Capital', 'GM Financial', 'Ally Financial', 'NMAC', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'Ford Motor Credit Co.', 'Nissan Motor Acceptance Corp.', 'Toyota Financial Services', 'Changan Automobile Co.', 'Honda', 'Chase', 'VW', 'Nissan', 'Toyota', 'Volkswagen AG', 'BMW', 'Renault', 'Honda Motor Co.', 'Nissan Motor Co.', 'Santander Consumer USA']
# ['FAW', 'SAIC', 'FAW Group', 'SAIC Motor', 'Daimler', 'GM', 'Ford', 'Volkswagen', 'Byton', 'Hyundai Motor Co.', 'Tesla', 'Ford Motor Co.', 'Volkswagen AG']
# ['FAW', 'SAIC', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen Group', 'VW', 'China FAW Group Corp.', 'Ford Motor', 'Audi', 'Jianghuai Automobile Co.', 'Volkswagen AG', 'Ford', 'Ford Motor Co.', 'Bentley', 'Porsche', 'SAIC Motor', "Volkswagen Group's", 'Lincoln', 'GM', 'Toyota', 'FAW Group', 'FCA']
# ['Continental', 'Delphi', 'Mitsubishi', 'Nissan', 'Guangzhou Automobile Group', 'Renault', 'Peugeot', 'Hyundai', 'Mazda', 'Suzuki', 'Honda Motor Co.', 'Toyota Motor Corp.', 'Guangzhou Automobile Group Co.', 'Waymo', 'Mitsubishi Motors']
# ['AutoNation', 'Daimler', 'Delphi', 'Ford', 'Intel', 'Microsoft', 'Nissan', 'Renault', 'Fiat', 'Lyft', 'Waymo', 'Honda', 'Jaguar', 'Fiat Chrysler Automobiles', 'Jaguar Land Rover', 'Walmart', 'FCA', 'JLR']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['fintech', 'Jaguar Land Rover', 'Maserati', 'Chase', 'Mazda', 'Subaru', 'Haig Partners', 'BMW', 'Daimler', 'Mitsubishi', 'Renault']
# ['Carvana', 'NYSE', 'SpringboardAuto', 'AutoGravity', 'fintech', 'Toyota Financial Services', 'Ford Motor Credit Co.', 'Ford Motor Co.', 'Magna International', 'Ford']
# ['Ford', 'GM', 'Honda Motor Co.', 'Volvo', 'Uber Technologies', 'Aptiv', 'Panasonic Corp.', 'Amazon', 'Mazda', 'Uber', 'fintech', 'Volkswagen']
# ['Bosch', 'Continental', 'Ford Motor Co.', 'General Motors', 'Mcity', 'Toyota Motor Corp.', 'Google', 'Audi', 'Fiat', 'Apple', 'Amazon', 'Chrysler', 'Fiat Chrysler', 'Ford', 'Mitsubishi', 'Nissan', 'Renault', 'AutoNation', 'Walmart', 'Honda', 'Hyundai']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['BMW', 'Daimler', 'Jaguar Land Rover', 'BAIC Group', 'Magna International Inc.', 'Beijing Auto', 'Magna International', 'Singulato Motors', 'Singulato', 'Bosch', 'Continental']
# ['Barclays', 'Goldman Sachs', 'GM', 'Goldman Sachs Group Inc.', 'Lyft', 'Morgan Stanley', 'Volkswagen Group', 'Citigroup Inc.', 'Geely', 'Tesla']
# ['Goldman Sachs', 'Morgan Stanley', 'Daimler', 'EV', 'Hyundai', 'Ford Motor Co.', 'Toyota Motor Corp.', 'Tesla', 'BMW', 'Mercedes-Benz', 'Geely', 'Goldman Sachs Group Inc.', 'Musk', 'Ford', 'Wilson', 'Harley-Davidson', 'Amazon', 'Apple', 'Apple Inc.', 'Google', 'Fiat Chrysler Automobiles', 'General Motors', 'Dura']
# ['EU', 'European Union', 'the European Union', 'Unifor', 'Opel', 'Ford', 'Ford Motor Co.', 'Volkswagen Group', 'BMW', 'Nissan', 'Volkswagen', 'Hyundai', 'Mazda', 'Suzuki', 'CATL', 'LG Chem', 'Samsung', 'Renault', 'BASF', 'Daimler']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['FAW', 'SAIC', 'Audi', 'Porsche', 'Volkswagen Group', 'VW', 'AC', 'BMW', 'Daimler', 'EVs', 'Ford', 'VW Group', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen', 'Tata Motors', 'Ford Motor Co.', 'Jianghuai Automobile Co.']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']
# ['Fiat', 'PSA', 'Continental', 'Delphi', 'Renault', 'Fiat Chrysler', 'Peugeot', 'Ferrari', 'Fiat Chrysler Automobiles', 'Guangzhou Automobile Group', 'Mitsubishi', 'Nissan', 'BMW', 'Intel', 'Mitsubishi Motors', "Fiat Chrysler's", 'Chrysler', 'GM', 'Volkswagen']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['GM', 'SAIC', 'Changan Automobile Co.', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'General Motors Co.', 'Lyft', 'Michelin', 'Daimler', 'EV', 'Nikola', 'Audi AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Tesla', 'Ford', 'PSA Group', 'Nissan', 'Ford Motor Co.']
# ['Deloitte', 'Ford Motor Co.', 'Volkswagen AG', 'Barra', 'EVs', 'Ford', 'GM', 'VW', 'Mitsubishi', 'Nissan', 'Renault', 'General Motors', 'OnStar', 'SoftBank', 'Lyft Inc.', 'Uber Technologies Inc.', 'Waymo', 'Toyota Motor Corp.', 'Tesla Inc.', 'Toyota']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['FAW', 'SAIC', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen Group', 'VW', 'China FAW Group Corp.', 'Ford Motor', 'Audi', 'Jianghuai Automobile Co.', 'Volkswagen AG', 'Ford', 'Ford Motor Co.', 'Bentley', 'Porsche', 'SAIC Motor', "Volkswagen Group's", 'Lincoln', 'GM', 'Toyota', 'FAW Group', 'FCA']
# ['Harley-Davidson Inc.', 'European Union', 'Audi', 'Harley-Davidson', 'Panasonic', 'Qualcomm', 'Porsche', 'District Court', 'EEOC', 'Chevrolet', 'Maserati', 'Subaru']
# ['European Union', 'EU', 'Daimler', 'Volkswagen', 'Fiat Chrysler Automobiles', 'PSA Group', 'BMW', 'Fiat', 'PSA', 'Renault']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Renault SA', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Microsoft']
# ['AutoNation', 'Daimler', 'Delphi', 'Ford', 'Intel', 'Microsoft', 'Nissan', 'Renault', 'Fiat', 'Lyft', 'Waymo', 'Honda', 'Jaguar', 'Fiat Chrysler Automobiles', 'Jaguar Land Rover', 'Walmart', 'FCA', 'JLR']
# ['Ford', 'PSA', 'Peugeot', 'Suzuki', 'Ford Motor Co.', 'Mazda Motor Corp.', 'Changan Automobile Co.', 'Suzuki Motor Corp.', 'Changan', 'GM', 'Mazda', 'FAW', 'Volkswagen']
# ['Mitsubishi Motors Corp.', 'Isuzu', 'Subaru', 'Toyota', 'Honda Motor Co.', 'General Motors', 'Mazda', 'Suzuki', 'Daihatsu', 'Honda', 'Fuji Heavy Industries', 'Ford', 'Mitsubishi', 'Renault', 'Ford Motor Co.', 'Magna International']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'BMW', 'Daimler', 'European Union', 'BMW Group', 'Kia', 'Pony.ai', 'Dongfeng Motor Corp.', 'AutoGravity', 'Aurora', 'EV', 'Fiat', 'CDK Global', 'Honda', 'Nissan', 'Toyota', 'Tencent Holdings', 'General Motors', 'Nvidia', 'Volkswagen']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['GM', 'SAIC', 'Changan Automobile Co.', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'General Motors Co.', 'Lyft', 'Michelin', 'Daimler', 'EV', 'Nikola', 'Audi AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Tesla', 'Ford', 'PSA Group', 'Nissan', 'Ford Motor Co.']
# ['BMW Group', 'Ford Motor Co.', 'VW Group', 'VW', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'Daimler', 'GM', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'FAW', 'SAIC', 'FAW Group', 'GAC', 'Guangzhou Automobile Group', 'BMW', 'Ford', 'Volkswagen', 'ChargePoint', 'EVgo', 'BMW AG', 'Daimler AG', 'General Motors', 'Nissan Motor Co.', 'Panasonic', 'Toyota', 'China FAW Group Corp.', 'Mitsubishi', 'Renault', 'Magna International', 'Alliance Ventures']
# ['AutoNation', 'TrueCar', 'Waymo', 'Fair', 'Google', 'CDK', 'Asbury Automotive Group', 'Penske Automotive Group', 'nonluxury', 'Vroom']
# ['Guangzhou Automobile Group Co.', 'BMW Group', 'Intel', 'Ferrari', 'Fiat Chrysler', 'Renault', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Ford Motor Co.', 'GM', 'Goldman Sachs Group Inc.', 'PSA Group', 'BMW', 'Continental', 'Delphi', 'Fiat Chrysler Automobiles', 'Guangzhou Automobile Group', 'Aurora', 'Nissan', 'Aurora Innovation', "Fiat Chrysler's", 'Ford', 'General Motors Co.', 'Volkswagen Group', 'Peugeot', 'Mitsubishi', 'PSA', 'Volkswagen', 'Google']
# ['BMW', 'Jaguar Land Rover', 'Chery Automobile Co.', "Jaguar Land Rover's", 'Tata Motors', 'Audi', 'Mercedes', 'Porsche', 'General Motors', 'Toyota', 'Mercedes-Benz']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'Kia', 'BMW', 'Daimler', 'Hyundai Motor', 'Aptiv', 'Hyundai', 'Pony.ai', 'Dongfeng Motor Group', 'Dongfeng Motor Corp.', 'BAIC Group', 'Hertz', 'Kia Motors']
# ['Dongfeng Motor Group', 'Hyundai Motor Co.', 'Hyundai Motor', 'Kia Motors Corp.', 'NBA', 'NFL', 'Bosch', 'Delphi', 'Denso', 'Dongfeng Motor Corp.', 'Kia', 'Kia Motors', 'Hyundai', 'Nissan', 'Kia Motors America']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['EU', 'the European Union', 'Opel', 'Ford', 'Ford Motor Co.', 'Volkswagen Group', 'BMW', 'Nissan', 'Volkswagen', 'Audi', 'Daimler', 'Porsche', 'VW', 'CATL', 'LG Chem', 'Samsung', 'BASF', 'Renault', 'FCA US', 'Fiat']
# ['Audi', 'Daimler', 'BMW Group', 'Intel', 'BMW', 'Ford', 'VW Group', 'Ford Motor Co.', 'Porsche', "Volkswagen Group's", 'Audi AG', 'Chongqing Changan Automobile Co.', 'Continental', 'Delphi', 'Fiat Chrysler Automobiles', 'Nissan', 'Renault', 'Apple', 'Google', 'Volkswagen Group', 'DriveNow']
# ['Dongfeng Motor Group', 'Hyundai Motor Co.', 'Kia Motors Corp.', 'Hyundai', 'Kia', 'NBA', 'NFL', 'Dongfeng Motor Corp.', 'Hyundai Motor']
# ['Toyota Motor Corp.', 'Guangzhou Automobile Group', 'Toyota', 'Hyundai', 'Pony.ai', 'Daimler']
# ['Honda', 'Nissan', 'PSA', 'Peugeot', 'Honda Motor Co.', 'Nissan Motor Co.', 'Renault', 'Kia', 'Kia Motors Corp.', 'Dongfeng', 'Suzuki', 'Honda Motor', 'Kia Motors', 'Nissan Motor', 'PSA Group', 'Dongfeng Motor Corp.', "General Motors'", 'SAIC Motor', 'Renault SA']
# ['OEM', 'AutoGravity', 'Mercedes-Benz', 'Volkswagen Group', 'Daimler AG', 'Mercedes-Benz Financial Services', 'Volkswagen Credit', 'Westlake Financial Services']
# ['Byton', 'Hyundai Motor Co.', 'Volkswagen Group', 'Volkswagen AG', 'Hyundai', 'Volkswagen', 'Nvidia', 'Hyundai Motor', 'Fiat', 'Aurora', 'Google', 'Tesla']
# ['BMW Group', 'Ford Motor Co.', 'VW Group', 'VW', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'Daimler', 'GM', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'FAW', 'SAIC', 'FAW Group', 'GAC', 'Guangzhou Automobile Group', 'BMW', 'Ford', 'Volkswagen', 'ChargePoint', 'EVgo', 'BMW AG', 'Daimler AG', 'General Motors', 'Nissan Motor Co.', 'Panasonic', 'Toyota', 'China FAW Group Corp.', 'Mitsubishi', 'Renault', 'Magna International', 'Alliance Ventures']
# ['Fiat', 'PSA', 'Continental', 'Delphi', 'Renault', 'Fiat Chrysler', 'Peugeot', 'Ferrari', 'Fiat Chrysler Automobiles', 'Guangzhou Automobile Group', 'Mitsubishi', 'Nissan', 'BMW', 'Intel', 'Mitsubishi Motors', "Fiat Chrysler's", 'Chrysler', 'GM', 'Volkswagen']
# ['CDK', 'Nissan Motor Acceptance Corp.', 'Reynolds', 'CDK Global', 'Microsoft', 'Lithia Motors Inc.', 'Sonic Automotive Inc.']
# ['BMW', 'Nissan', 'Waymo', 'Changan Automobile Co.', 'Isuzu', 'GM', 'Daimler', 'Hyundai', 'Toyota', 'General Motors', 'EV', 'AutoNation', 'Fiat Chrysler', 'Jaguar Land Rover']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Renault SA', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Microsoft']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['Foxconn', 'Tencent', 'Tesla', 'Guangzhou Automobile Group', 'Tencent Holdings', 'Alibaba Group Holding', 'Audi AG', 'BMW AG', 'Daimler AG', 'Baidu', 'Tesla Inc.', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'Fiat Chrysler', 'Honda', 'Mitsubishi', 'Toyota', 'Baidu Inc.']
# ['GM', 'SAIC', 'Changan Automobile Co.', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'General Motors Co.', 'Lyft', 'Michelin', 'Daimler', 'EV', 'Nikola', 'Audi AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Tesla', 'Ford', 'PSA Group', 'Nissan', 'Ford Motor Co.']
# ['Uber', 'Volkswagen', 'SF Motors', 'Singulato Motors', 'Volkswagen AG', 'Intel', 'BMW', 'Delphi', 'Audi', 'Bosch', 'Mercedes-Benz', 'Tesla', 'Volvo', 'Autoliv', 'Hella', 'Toyota Motor Corp.', 'Volkswagen Group', 'Nvidia', 'AB Volvo', 'SAIC', 'Aurora', 'Baidu', 'Harman', 'Panasonic', 'Hyundai']
# ...
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'GM', 'Changan Automobile Co.', 'Volkswagen Group', 'VW', 'Daimler', 'General Motors Co.', 'Toyota Motor Corp.']
# ['BMW', 'Daimler', 'Ford', 'VW Group', 'VW', 'Audi', 'Porsche', "Volkswagen Group's", 'Volkswagen', 'SAIC Motor Corp.', 'FAW', 'Volkswagen AG', 'SAIC Motor', 'Bentley', 'Tata Motors', 'Ford Motor', 'Hyundai', 'Argo AI', 'Traton']
# ['Ford', 'GM', 'NADA', 'Ford Motor Co.', 'Lincoln', 'Cadillac', 'Harman', 'Lincoln MKX', 'Jaguar', 'Volvo', 'Ford Credit', 'Lexus', 'Porsche']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['Amazon', 'Mazda', 'Uber', 'FAW Group', 'Guangzhou Automobile Group', 'Mazda Motor Corp.', 'GAC', 'Dongfeng Motor Corp.', 'Guangzhou Automobile Group Co.', 'Denso Corp.', 'EVs', 'Toyota Motor Corp.', 'Fuji Heavy Industries', 'Subaru', 'Suzuki', 'Panasonic', 'Apple Inc.', 'Mitsubishi', 'PSA', 'Peugeot', 'Volkswagen Group']
# ['Mazda', 'Toyota', 'Volkswagen', 'Changan Automobile Co.', 'Honda', 'Nissan', 'FAW Group', 'VW', 'Ford', 'FAW', 'Daimler', 'Toyota Motor', 'Volkswagen Group', 'Audi', 'Toyota Motor Corp.', 'Volkswagen AG', 'FAW-VW', 'the Volkswagen Group', 'General Motors']
# ['Continental', 'Delphi', 'Mitsubishi', 'Nissan', 'Guangzhou Automobile Group', 'Renault', 'Peugeot', 'Hyundai', 'Mazda', 'Suzuki', 'Honda Motor Co.', 'Toyota Motor Corp.', 'Guangzhou Automobile Group Co.', 'Waymo', 'Mitsubishi Motors']
# ['Ford', 'GM', 'Honda Motor Co.', 'Volvo', 'Uber Technologies', 'Aptiv', 'Panasonic Corp.', 'Amazon', 'Mazda', 'Uber', 'fintech', 'Volkswagen']
# ['Bosch', 'Continental', 'Ford Motor Co.', 'General Motors', 'Mcity', 'Toyota Motor Corp.', 'Google', 'Audi', 'Fiat', 'Apple', 'Amazon', 'Chrysler', 'Fiat Chrysler', 'Ford', 'Mitsubishi', 'Nissan', 'Renault', 'AutoNation', 'Walmart', 'Honda', 'Hyundai']
# ['Geely', 'Daimler', 'Intel', 'Toyota Motor Corp.', 'BMW', 'Tencent Holdings', 'Uber', 'Volvo', 'Toyota', 'Lotus', 'Geely Automobile Holdings', 'LEVC', 'Volvo Cars']
# ['F&I', 'Toyota Motor Corp.', 'Southeast Toyota Distributors', 'JM&A Group', 'Volvo', 'JM&A', 'JM Family Enterprises']
# ['Citigroup Inc.', 'Goldman Sachs Group Inc.', 'Morgan Stanley', 'Volvo', 'BMW Group', 'Daimler', 'Geely Auto', 'Ford Motor Co.', 'Volkswagen Group', 'Geely Automobile', 'Volvo Car Corp.', 'Baidu Inc.', 'Geely', 'Toyota', 'Toyota Motor Corp.', 'Zhejiang Geely Holding Group', 'Volvo Cars', 'Lynk & CO', 'BorgWarner Inc.', 'Fiat', 'Tencent Holdings']
# ['Geely Auto', 'Volvo', 'Zhejiang Geely Holding', 'Geely', 'Zhejiang Geely Holding Group', 'Lynk & CO', 'Volvo Car Corp.', 'Geely Automobile Holdings', "Lynk & CO's", 'Geely Automobile']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['FAW', 'SAIC', 'FAW Group', 'SAIC Motor', 'Daimler', 'GM', 'Ford', 'Volkswagen', 'Byton', 'Hyundai Motor Co.', 'Tesla', 'Ford Motor Co.', 'Volkswagen AG']
# ['Geely', 'Zhejiang Geely Holding Group', 'Citigroup Inc.', 'Goldman Sachs Group Inc.', 'Morgan Stanley', 'Volvo', 'Zhejiang Geely', 'Daimler', 'Daimler AG', 'Nvidia', 'AB Volvo']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Uber', 'Volkswagen', 'SF Motors', 'Singulato Motors', 'Volkswagen AG', 'Intel', 'BMW', 'Delphi', 'Audi', 'Bosch', 'Mercedes-Benz', 'Tesla', 'Volvo', 'Autoliv', 'Hella', 'Toyota Motor Corp.', 'Volkswagen Group', 'Nvidia', 'AB Volvo', 'SAIC', 'Aurora', 'Baidu', 'Harman', 'Panasonic', 'Hyundai']
# ['Contemporary Amperex Technology Co.', 'LG Chem', 'Panasonic', 'Panasonic Corp.', 'Denso Corp.', 'Apple Inc.', 'Toyota', 'Intel', 'Nvidia', 'FAW Group', 'SAIC Motor', 'Apple', 'Google']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'Kia', 'BMW', 'Daimler', 'Hyundai Motor', 'Aptiv', 'Hyundai', 'Pony.ai', 'Dongfeng Motor Group', 'Dongfeng Motor Corp.', 'BAIC Group', 'Hertz', 'Kia Motors']
# ['BYD', 'Daimler', 'ABB', 'EV', 'Volvo', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'GM', 'Delphi', 'Volkswagen', 'VW', 'Northvolt', 'Mitsubishi', 'Renault', 'Ford', 'Ford Motor Co.']
# ['Apple Inc.', 'FAW', 'Volkswagen', 'Porsche', "Volkswagen Group's", 'BMW', 'Daimler', 'AT&T', 'VW', 'SAIC', 'Ford Motor Co.', 'AutoGravity', 'Audi AG', 'General Motors', 'Hyundai', 'Continental', 'Jeep', 'Mercedes-Benz', 'FAW Group', 'VW Group', 'Apple', 'Google', 'Toyota']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['BMW', 'Daimler', 'Intel', 'Daimler AG', 'FAW', 'SAIC', 'AutoGravity', 'Mercedes-Benz Financial Services', 'Baidu', 'Mercedes', 'Bosch', 'Panasonic', 'Toyota', 'BAIC', 'Nissan', 'Audi', 'General Motors', 'Volkswagen Group', 'FCA', 'Google', 'Ford Motor Co.', 'Magna International']
# ['Citigroup Inc.', 'Goldman Sachs Group Inc.', 'Morgan Stanley', 'Geely Auto', 'Volvo', 'BMW Group', 'Daimler', 'Geely Automobile', 'Proton', 'Baidu Inc.', 'Geely', 'Toyota', 'Toyota Motor Corp.', 'Zhejiang Geely Holding Group', 'Volvo Car Corp.', 'Tencent Holdings']
# ['Fiat Chrysler', 'GM', 'Nissan Motor Co.', 'Volkswagen', 'BMW AG', 'Daimler AG', 'BMW', 'Daimler', 'Mercedes-Benz', 'VW', 'Nissan', 'Chevrolet', 'ChargePoint', 'EVgo', 'Siemens']
# ['ChargePoint', 'Honda Motor Co.', 'LG Chem', 'GM', 'Nikola', 'BMW', 'Nissan', 'Daimler', 'Ford', 'Volkswagen', 'EV', 'EVgo', 'General Motors', 'Audi', 'VW', 'Mitsubishi', 'Renault', 'Ford Motor Co.']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['Audi', 'Italdesign', 'Porsche', 'Airbus', 'Daimler', 'Volvo', 'Volkswagen Group', 'VW Group', 'Nissan', 'Apple', 'VW', 'MEB', 'Mitsubishi', 'Renault', 'Ford', 'Ford Motor Co.', 'Magna International']
# ['Amazon', 'Google', 'Geely', 'JM&A Group', 'Zhejiang Geely Holding Group', 'Lynk & CO', 'Ford', 'VW', 'AB Volvo', 'Daimler', 'Nvidia', 'Tesla', 'Hyundai Motor Co.', 'ABB', 'Audi', 'BMW', 'Mercedes', 'Zhejiang Geely Holding']
# ['General Motors', 'Volkswagen', 'GM', 'Volkswagen Group', 'SAIC', 'Changan Automobile Co.', 'SAIC Motor Corp.', 'Daimler', 'the Volkswagen Group']
# ['FAW', 'SAIC', 'FAW Group', 'SAIC Motor', 'Daimler', 'GM', 'Ford', 'Volkswagen', 'Byton', 'Hyundai Motor Co.', 'Tesla', 'Ford Motor Co.', 'Volkswagen AG']
# ['Apple Inc.', 'FAW', 'Volkswagen', 'Porsche', "Volkswagen Group's", 'BMW', 'Daimler', 'AT&T', 'VW', 'SAIC', 'Ford Motor Co.', 'AutoGravity', 'Audi AG', 'General Motors', 'Hyundai', 'Continental', 'Jeep', 'Mercedes-Benz', 'FAW Group', 'VW Group', 'Apple', 'Google', 'Toyota']
# ['BMW', 'Daimler', 'Ford', 'VW Group', 'VW', 'Audi', 'Porsche', "Volkswagen Group's", 'Volkswagen', 'SAIC Motor Corp.', 'FAW', 'Volkswagen AG', 'SAIC Motor', 'Bentley', 'Tata Motors', 'Ford Motor', 'Hyundai', 'Argo AI', 'Traton']
# ['FAW', 'SAIC', 'Audi', 'Porsche', 'Volkswagen Group', 'VW', 'AC', 'BMW', 'Daimler', 'EVs', 'Ford', 'VW Group', 'China FAW Group', 'SAIC Motor Corp.', 'Volkswagen', 'Tata Motors', 'Ford Motor Co.', 'Jianghuai Automobile Co.']
# ['Apple', 'Mercedes-Benz', 'Acura', 'Honda', 'Volkswagen', 'Tesla', 'Google', 'AT&T', 'Ford Motor Co.', 'Continental AG', 'Daimler', 'Porsche', 'Tesla Inc.', 'J.D. Power', 'Aurora Innovation', 'VW', 'Apple Inc.', 'Fiat Chrysler Automobiles', 'Lyft Inc.', 'General Motors']
# ['Daimler', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Audi', 'Intel', 'Audi AG', 'Ford Motor Co.', 'Continental', 'Delphi', 'BMW Group', 'Nissan', 'Renault', 'Apple', 'Google', 'Mercedes-Benz', 'Ford', 'Toyota']
# ['Hyundai Motor Co.', 'Kia Motors Corp.', 'BMW', 'Daimler', 'European Union', 'BMW Group', 'Kia', 'Pony.ai', 'Dongfeng Motor Corp.', 'AutoGravity', 'Aurora', 'EV', 'Fiat', 'CDK Global', 'Honda', 'Nissan', 'Toyota', 'Tencent Holdings', 'General Motors', 'Nvidia', 'Volkswagen']
# ['Koenigsegg', 'Saab', 'EV', 'Evergrande', 'BMW AG', 'McLaren', 'Porsche', 'supercar', 'Ford', 'Ford Motor Co.']
# ['Mahindra', 'Pininfarina', 'Mahindra & Mahindra']
# ['Mitsubishi', 'Nissan', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Dongfeng', 'Renault', 'Ghosn', 'Mitsubishi Motors']
# ['Boeing', 'Porsche', 'Audi', 'Daimler', 'Geely Automobile Holdings', "Volkswagen Group's", 'Pentagon', 'Airbus', 'Italdesign', 'BP', 'Subaru Corp.', 'Ford', 'Alliance Ventures', 'Ford Motor Co.', 'Magna International']
# ['Porsche', 'Boxster', 'Audi', 'BMW', 'Macan', 'Tesla', 'Volkswagen', 'Ford Motor Co.', 'FCA', 'Google', 'Magna International']
# ['European Union', 'EU', 'Daimler', 'Volkswagen', 'Fiat Chrysler Automobiles', 'PSA Group', 'BMW', 'Fiat', 'PSA', 'Renault']
# ['SAIC Motor Corp.', 'VW', 'Piech', 'Porsche', 'VW Group', 'Volkswagen', 'Audi', 'Winterkorn', 'Siemens']
# ['Volkswagen AG', 'Lamborghini', 'Pininfarina', 'Volkswagen Group', 'Bugatti', 'Bentley', 'Rolls-Royce', 'BMW', 'Jaguar Land Rover', 'Nissan', 'Audi', 'Porsche', 'Maserati', 'VW Group', 'Ferrari', 'Jaguar', 'Mercedes-AMG']
# ['Volkswagen Group', 'Audi', 'Porsche', 'Skoda', 'Bugatti', 'VW Group', 'ultraluxury', 'Volkswagen', 'Bentley', 'Lamborghini', 'Rolls-Royce', 'FCA', 'Google', 'Ford Motor Co.', 'Magna International']
# ['Volkswagen', 'Bentley', 'Lamborghini', 'Porsche', 'VW', 'Volkswagen Group', 'Maserati', 'Ferrari', 'Amazon', 'the Massachusetts Institute of Technology', 'MIT', 'Bugatti', 'Audi', 'Reggiani', 'the Volkswagen Group', 'Rolls-Royce']
# ['Goldman Sachs Group Inc.', 'Ferrari', 'Fiat Chrysler', 'Ford Motor Co.', 'GM', 'General Motors', 'UBS', 'Alfa', 'Fiat', 'CNH Industrial', 'Fiat Chrysler Automobiles', 'Facebook', 'Penske', 'Maserati', 'Penske Automotive Group']
# ['Alfa', 'Ferrari', 'Maserati', 'Citroen', 'Mitsubishi', 'Nissan', 'Alfieri', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'FCA', 'Bentley', 'supercar', 'Renault', 'Guangzhou Automobile Group', 'Fiat', 'BMW', 'Mercedes-Benz', 'Audi', 'Mercedes']
# ['Haig Partners', 'Group 1 Automotive Inc.', 'Penske Automotive Group Inc.', 'Honda', 'Toyota', 'Asbury Automotive Group Inc.', 'AutoNation Inc.', 'OEM', 'Apollo']
# ['Kerrigan', 'Haig Partners', 'Ford Motor Co.', 'Magna International', 'Mitsubishi', 'Renault', 'Alliance Ventures', 'Asbury Automotive Group Inc.', 'AutoNation Inc.', 'Group 1 Automotive Inc.', 'Penske Automotive Group Inc.']
# ['BMW', 'Daimler', 'Intel', 'Daimler AG', 'FAW', 'SAIC', 'AutoGravity', 'Mercedes-Benz Financial Services', 'Baidu', 'Mercedes', 'Bosch', 'Panasonic', 'Toyota', 'BAIC', 'Nissan', 'Audi', 'General Motors', 'Volkswagen Group', 'FCA', 'Google', 'Ford Motor Co.', 'Magna International']
# ['Honda', 'Chongqing Changan Automobile Co.', 'SAIC', 'SAIC Motor Corp.', 'Changan Automobile Co.', 'LG Chem', 'Ultium', 'Ford Motor Co.', 'Google', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Amazon', 'Ford', 'Chevrolet', 'Omnicom']
# ['General Motors', 'Volkswagen', 'Volkswagen AG', 'SAIC Motor Corp.', 'SAIC', 'Volkswagen Group', 'GM', 'Wuling', 'Buick', 'Cadillac', 'Chevrolet', 'the Volkswagen Group', 'Suzuki Motor Corp.', 'General Motors Co.']
# ['Ford', 'PSA', 'Peugeot', 'Suzuki', 'Ford Motor Co.', 'Mazda Motor Corp.', 'Changan Automobile Co.', 'Suzuki Motor Corp.', 'Changan', 'GM', 'Mazda', 'FAW', 'Volkswagen']
# ['Nissan', 'Renault', 'Apple', 'Google', 'Mitsubishi', 'Nissan Motor Co.', 'Mitsubishi Motors', 'Chrysler', 'Mitsubishi Motors Corp.', 'GAC', 'Renault SA', 'Alliance']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Mitsubishi Motors Corp.', 'Microsoft', 'Nissan', 'Infiniti', 'Nissan Motor Co.', 'Dongfeng Motor Group', 'Toyota', 'Volkswagen', 'Renault SA', 'FCA', 'Audi AG', 'Mercedes-Benz', 'Hertz']
# ['Changan Automobile Co.', 'GM', 'SAIC', 'Ford', 'Mazda', 'Toyota', 'FAW Group', 'Guangzhou Automobile Group', "BMW Group's", 'Toyota AI Ventures', "Toyota Motor Corp.'s", 'General Motors', 'Honda', 'Fiat Chrysler Automobiles NV', 'Jaguar', 'Waymo', 'Delphi Automotive', 'Volkswagen', 'Ford Motor Co.', 'PSA Group', 'Nissan', 'Apple', 'Google']
# ['Alphabet Inc.', 'Drive.ai', 'Ford Motor Co.', 'General Motors Co.', 'Jaguar Land Rover', 'Lyft', 'Waymo', 'Google', 'Alphabet', 'General Motors', 'Maven', 'Uber Technologies', 'Flexdrive', 'NuTonomy']
# ['Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Nissan', 'Mitsubishi', 'Renault', 'Mitsubishi Motors', 'General Motors', 'Ford', 'BMW Group']
# ['Audi', 'Porsche', "Volkswagen Group's", 'BAIC', 'Geely', 'Intel', 'BMW', 'Daimler AG', 'Nissan Motor', 'Renault', 'Volvo', 'Baidu', 'Qualcomm', 'Nissan', 'BAIC Motor Group Co.', 'Microsoft']
# ['BMW Group', 'Ford Motor Co.', 'VW Group', 'VW', 'Hyundai', 'Jaguar', 'Land Rover', 'Mahindra', 'Nissan', 'Daimler', 'GM', 'Fiat Chrysler Automobiles', 'Honda Motor Co.', 'Mitsubishi Motors Corp.', 'Toyota Motor Corp.', 'FAW', 'SAIC', 'FAW Group', 'GAC', 'Guangzhou Automobile Group', 'BMW', 'Ford', 'Volkswagen', 'ChargePoint', 'EVgo', 'BMW AG', 'Daimler AG', 'General Motors', 'Nissan Motor Co.', 'Panasonic', 'Toyota', 'China FAW Group Corp.', 'Mitsubishi', 'Renault', 'Magna International', 'Alliance Ventures']
# ['Bosch', 'Iveco', 'General Motors', 'Nikola', 'CNH Industrial', 'Honda Motor Co.', 'LG Chem', 'Nikola Corp.', 'GM', 'Volkswagen Group']
# ['Daimler', 'GM', 'VW', 'Baidu', 'Audi AG', 'BMW AG', 'Daimler AG', 'Audi', 'BMW', 'Mercedes-Benz', 'FAW', 'SAIC Motor', 'Ford Motor Co.', 'General Motors', 'TK Holdings Inc.', 'SAIC', 'SAIC Motor Corp.', 'Volkswagen', 'China FAW Group Corp.', 'Volkswagen AG', 'Bentley', 'Porsche', 'Apple Inc.', 'Nissan Motor', 'Renault']
# ['BMW', 'Continental', 'Fiat', 'Intel', 'Chrysler', 'Goldman Sachs', 'Samsung', 'Delphi', 'Denso', 'BorgWarner', 'Delphi Automotive', 'Aptiv', 'Barclays', 'Valeo']
# ['Guangzhou Automobile Group Co.', 'Ford', 'VW', 'Chrysler', 'Jeep', 'Fiat Chrysler', 'Volkswagen AG', 'Fiat Chrysler Automobiles', 'Guangzhou Automobile Group', 'Aurora Innovation', 'PSA Group', 'BAIC Group', 'Renault', 'Chevrolet', 'Mitsubishi', 'Nissan', 'Fiat']
# ['Jaguar', 'Waymo', 'Rover', 'BMW Group', 'Zhejiang Geely Holding', 'Chery', 'General Motors Co.', 'BMW', 'Jaguar Land Rover', 'Ford', 'Bentley', 'Ford Motor Co.', 'Tata Motors']
# ['AutoNation', 'Daimler', 'Delphi', 'Ford', 'Intel', 'Microsoft', 'Nissan', 'Renault', 'Fiat', 'Lyft', 'Waymo', 'Honda', 'Jaguar', 'Fiat Chrysler Automobiles', 'Jaguar Land Rover', 'Walmart', 'FCA', 'JLR']
# ['Contemporary Amperex Technology Co.', 'LG Chem', 'Panasonic', 'Panasonic Corp.', 'Denso Corp.', 'Apple Inc.', 'Toyota', 'Intel', 'Nvidia', 'FAW Group', 'SAIC Motor', 'Apple', 'Google']
# ['Changan Automobile Co.', 'Ford Motor Co.', 'Volkswagen Group', 'Ford Motor', 'VW', 'Volkswagen', 'Baojun', "Nissan Motor Co.'s", 'Venucia', 'Changan']
# ['Fiat', 'PSA', 'PSA Group', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'GM', 'Toyota', 'Dongfeng Motor Corp.', 'Audi', 'BMW Group', 'Mercedes-Benz', 'Renault', 'Toyota Motor', 'Volkswagen Group', 'Dongfeng Motor Group', 'Peugeot']
# ['Mitsubishi Motors', 'Renault', 'Mitsubishi', 'Renault SA', 'Mitsubishi Motors Corp.', 'Nissan Motor Co.', 'Microsoft']
# ['Changan Automobile Co.', 'Chongqing Changan Automobile Co.', 'Daimler', 'Jiangling Motors Corp.', 'BAIC Group', 'Hyundai Motor Co.', 'Mazda Motor Corp.', 'BMW Group', 'Ford Motor Co.', 'VW Group', 'BMW AG', 'Delphi Automotive', 'Fiat Chrysler Automobiles', 'Intel Corp.', 'Lyft', 'Ford', 'VW', 'Volkswagen', 'Ford Motor', 'Magna International', 'Baojun', 'Nissan']

# %%
final_df.shape
# Out:
# (164, 3)

# %%
final_df_original = final_df.iloc[:20, :]
final_df_original['tp'] = np.array(tp_lst)
final_df_original['fp'] = np.array(fp_lst)
final_df_original['precision'] = np.array(precision_lst)
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.

# %%
final_df_original
# Out:
#             company  ... precision
# 0              Ford  ...  1.000000
# 1             Tesla  ...  0.461538
# 2                GM  ...  0.500000
# 3            Toyota  ...  0.619048
# 4            Nissan  ...  1.000000
# 5               BMW  ...  0.578947
# 6                VW  ...  0.538462
# 7                EV  ...  0.111111
# 8   Automotive News  ...  0.000000
# 9             Trump  ...  0.000000
# 10            Honda  ...  0.285714
# 11          Hyundai  ...  0.380952
# 12             Audi  ...  0.608696
# 13              FCA  ...  0.200000
# 14              F&I  ...  0.571429
# 15          Daimler  ...  0.812500
# 16       Volkswagen  ...  0.636364
# 17            Volvo  ...  0.555556
# 18          Porsche  ...  0.464286
# 19   General Motors  ...  0.333333
#
# [20 rows x 6 columns]

# %%
final_df_original.to_csv('final_df_original.csv')

# %%
final_df.to_csv('final_df.csv')

# %% [markdown]
# # Future improvments

# %% [markdown]
# Here is a list of things we can do to improve the results:
#
#
#
# 1.   First thing we should do, is to search the Internet, to find out whether we can enrich our datasets, specially the dataset in which we stored the company names. It's a major things in our pipeline, because we validated our results using this dataset several times during the pipeline, and  better quality in this data would absolutely improve our results.
# Also it was better to store this data on a database, instead of a dataframe, so we don't need to obtain it everytime we want to run the pipeline.
# 2.   In this notebook, we just used a sample of 50k articles from autonews.com website. Adding articles from other resources to our data, might cause that the retirever select better articles and therefore our precision might increase.
# 3.   In this notebook, we just used ElasticSearchRetriever (BM25) as our retriever model, but other models such as embedding models need to be tested. They might improve our pipeline results.
# 4.   Also, there are a bunch of other NLP models that could be used for Reader. Some of them might increase the presicion, or speed of our pipeline.
# 5.   Although the cross-validation idea isn't that bad, if we could find some ground truth information about partnership of companies with each other, it would help a lot to measure the precision of our pipeline more accurately.
# 6.   Furthermore, I run the pipeline for just 20 companies, so the results would be unreliable and it should be tested with a bigger sample.
# 7.   Finaly, it was better to store the results on a database to be easily achievable anytime we want, but since we are using an interactive environment and don't have access to servers, I just saved the results as a csv file.
